# %%
import numpy as np
import torch as th
from PIL import Image
import json, glob, os

sj_path = "/home/mint/Dev/DiFaReli/difareli-faster/experiment_scripts/TPAMI/sample_json/DiFaReli++/TargetSH_from_TR_figure.json"

method = ["TR", "hou_21", "hou_22", "IC-Light", "ours_256_DiFaReli", "ours_difareli++_oneshot_dstC"]
sample = json.load(open(sj_path, "r"))
meta = json.load(open("../ffhq_targetSH.json", "r"))
os.makedirs("./figures/", exist_ok=True)

for pid, dat in tqdm.tqdm(sample['pair'].items()):
    src = dat['src']
    dst = dat['dst']

    out = []
    for m in method:
        meta_dat = meta[m]
        img_dir = meta_dat['img_dir']
        itp_method = meta_dat['itp_method']
        diff_step = meta_dat['diff_step']
        n_frame = int(meta_dat['n_frame'])

        if m in ["TR", "hou_21", "hou_22"]:
            relit_img = f'{img_dir}/src={src}/dst={dst}/res_frame{n_frame-1}.png'
        else:
            relit_img = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/n_frames={n_frame}/res_frame{n_frame-1}.png'
        relit_img = Image.open(relit_img)
        out.append(relit_img)

        if m == "ours_difareli++_oneshot_dstC":
            shadm = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/n_frames={n_frame}/dst_shadm_shad_frame{n_frame-1}.png'
            ren = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/n_frames={n_frame}/dst_ren_frame{n_frame-1}.png'
            shadm = Image.open(shadm)
            ren = Image.open(ren)
            out_cond = np.concatenate([shadm, ren], axis=0)

    out = np.concatenate(out, axis=1)

    Image.fromarray(out).save(f"./figures/{pid}_res.png")
    Image.fromarray(out_cond).save(f"./figures/{pid}_cond.png")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~/miniconda3/envs/dpm_sampling_deca_pysh/lib/python3.8/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     503     try:
# --> 504         fh = fp.fileno()
#     505         fp.flush()
#
# AttributeError: '_idat' object has no attribute 'fileno'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_59837/3224553840.py in <module>
#      39     out = np.concatenate(out, axis=1)
#      40
# ---> 41     Image.fromarray(out).save(f"./figures/{pid}_res.png")
#      42     Image.fromarray(out_cond).save(f"./figures/{pid}_cond.png")
#      43
#
# ~/miniconda3/envs/dpm_sampling_deca_pysh/lib/python3.8/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2238
#    2239         try:
# -> 2240             save_handler(self, fp, filename)
#    2241         finally:
#    2242             # do what we can to clean up
#
# ~/miniconda3/envs/dpm_sampling_deca_pysh/lib/python3.8/site-packages/PIL/PngImagePlugin.py in _save(im, fp, filename, chunk, save_all)
#    1346         _write_multiple_frames(im, fp, chunk, rawmode)
#    1347     else:
# -> 1348         ImageFile._save(im, _idat(fp, chunk), [("zip", (0, 0) + im.size, 0, rawmode)])
#    1349
#    1350     if info:
#
# ~/miniconda3/envs/dpm_sampling_deca_pysh/lib/python3.8/site-packages/PIL/ImageFile.py in _save(im, fp, tile, bufsize)
#     516             else:
#     517                 while True:
# --> 518                     l, s, d = e.encode(bufsize)
#     519                     fp.write(d)
#     520                     if s:
#
# KeyboardInterrupt:
