# %%
import numpy as np
import torch as th
from PIL import Image
import matplotlib.pyplot as plt

path = "/data/mint/sampling/TPAMI/cast_shadows_results/log%3DDiFaReli_FsBg_Sdiff_SS_128_VLL_cfg%3DDiFaReli_FsBg_Sdiff_SS_128_VLL.yaml_inv_with_sd_rotateSH_axis2_SC/ema_100000/valid/render_face/reverse_sampling/src%3D66890.jpg/dst%3D60000.jpg/Lerp_1000/n_frames%3D60/shadm_shad_frame0.png"
path = path.replace("%3D", "=")

img = Image.open(path)
plt.imshow(img)
plt.show()

dat = "/data/mint/DPM_Dataset/ffhq_256_with_anno/shadow_diff_SS_with_c_simplified/valid/66890.npy"
img_npy = np.load(dat)
plt.imshow(img_npy)
plt.show()

print(np.unique(img_npy))
print(np.unique(np.array(img)))
# Out:
# [0.         0.22840706]
# [0]
