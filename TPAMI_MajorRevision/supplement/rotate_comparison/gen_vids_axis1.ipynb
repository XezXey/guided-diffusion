# %%
import json, os, glob, tqdm
from PIL import Image
import numpy as np
import subprocess

def sort_by_frame(path_list):
    frame_anno = []
    for p in path_list:
        frame_idx = os.path.splitext(p.split('/')[-1].split('_')[-1])[0][5:]   # 0-4 is "frame", so we used [5:] here
        frame_anno.append(int(frame_idx))
    sorted_idx = np.argsort(frame_anno)
    sorted_path_list = []
    for idx in sorted_idx:
      sorted_path_list.append(path_list[idx])
    return sorted_path_list

# %% [markdown]
# # FFHQ: RotateSH_axis1.json

# %%
ax = 1

sample_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/experiment_scripts/TPAMI/sample_json/TPAMI_MajorRevision/rotateSH_axis1.json", "r"))

method = ["hou21_rotate_axis=1", "hou22_rotate_axis=1", "diffusionrig_rotate_axis=1_0.7sh", "iclight_rotate_512x512_map_centered_axis1", "relipa_rotate_axis=1_0.6sh", "ours_difareli_rotate_rot1_0.7sh_250t", "ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh"]
meta_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/visualize_scripts/TPAMI/MajorRevision/figure/ffhq/rotateSH_axis1.json", "r"))


os.makedirs("./vids/", exist_ok=True)
os.makedirs(f'./vids/all_outputs/res/', exist_ok=True)
os.makedirs(f'./vids/all_outputs/misc/', exist_ok=True)

no_f1 = True
focus_src = [f'{f}.jpg' for f in [62848, 60208, 69757, 61234]]
use_offset = True
start_offset = 13
end_offset = 45
for sample_id, sample in tqdm.tqdm(sample_dat['pair'].items()):
    src = sample['src']
    dst = sample['dst']
    if src not in focus_src:
        continue
    for m in method:
        img_dir = meta_dat[m]['img_dir']
        n_frames = meta_dat[m]['n_frame']
        itp_method = meta_dat[m]['itp_method']
        diff_step = meta_dat[m]['diff_step']
        n_frame_tmp = meta_dat[m]['n_frame']
        os.makedirs(f'./vids/axis={ax}/{src}_{dst}/{m}/', exist_ok=True)
        if "hou21" in m or "hou22" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
        elif "iclight" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
        elif m == "diffusionrig_rotate_axis=1_0.7sh":
            img_path = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/n_frames={n_frame_tmp}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:]
        elif m == "relipa_rotate_axis=1_0.6sh":
            img_path = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/gs=4.5_ds=25/n_frames={n_frame_tmp}/256/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:]
        elif "difareli++" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:][start_offset:end_offset]
                shadow = sort_by_frame(glob.glob(f'{img_path}/dst_shadm_shad_f*.png'))[1:][start_offset:end_offset]
                render = sort_by_frame(glob.glob(f'{img_path}/dst_ren_f*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
                shadow = sort_by_frame(glob.glob(f'{img_path}/dst_shadm_shad_f*.png'))[1:]
                render = sort_by_frame(glob.glob(f'{img_path}/dst_ren_f*.png'))[1:]
            for _, (s, r) in enumerate(zip(shadow, render)):
                i = int(s.split('/')[-1].split('frame')[-1].split('.')[0])
                assert i == int(r.split('/')[-1].split('frame')[-1].split('.')[0])
                os.system(f'cp {s} ./vids/axis={ax}/{src}_{dst}/{m}/dst_shadm_shad_frame_{i:04d}.png')
                os.system(f'cp {r} ./vids/axis={ax}/{src}_{dst}/{m}/dst_ren_frame_{i:04d}.png')

            assert len(relit) == len(shadow) == len(render)
            for j in range(len(relit)):
                frame_id = int(relit[j].split('/')[-1].split('frame')[-1].split('.')[0])
                r_tmp = np.array(Image.open(relit[j]))
                h, w, _ = r_tmp.shape
                s_tmp = np.array(Image.open(shadow[j]).resize((h//2, w//2)))
                ren_tmp = np.array(Image.open(render[j]).resize((h//2, w//2)))
                
                out_comb = np.concatenate((r_tmp, np.concatenate((ren_tmp, s_tmp), axis=0)), axis=1)
                Image.fromarray(out_comb).save(f'./vids/axis={ax}/{src}_{dst}/{m}/res+cond_frame_{frame_id:04d}.png')
             
            if use_offset:   
                start_num = start_offset
            else:
                start_num = 0
            cmds = [f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/{m}/dst_shadm_shad_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/shadow.mp4',
                    f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/{m}/dst_ren_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/render.mp4',
                    # Vertical stack them (render on top of shadow)
                    f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/render.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/shadow.mp4 -filter_complex vstack ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4',
                    f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4'
            ]
            for c in cmds:
                try:
                    subprocess.run(c, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
                except subprocess.CalledProcessError as e:
                    print("An error occurred:", e)
        
        
            
        elif "difareli" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
        
        if len(relit) == 0:
            # Create 0 images for mockup and match the number of frames
            for i in range(1, int(n_frames)):
                img = Image.new('RGB', (256, 256), color='black')
                img.save(f'./vids/axis={ax}/{src}_{dst}/{m}/res_frame_{i:04d}.png')
            continue
        
        os.makedirs(f'./vids/axis={ax}/{src}_{dst}/{m}/', exist_ok=True)
        # Copy all images to a new folder
        for img in relit:
            i = int(img.split('/')[-1].split('frame')[-1].split('.')[0])
            os.system(f'cp {img} ./vids/axis={ax}/{src}_{dst}/{m}/res_frame_{i:04d}.png')
        
        #NOTE: Generate video low compression with 24 fps
        if use_offset:
            start_num = start_offset
        else:
            start_num = 0
        cmd = f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/{m}/res_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/res_{m}.mp4'
        os.system(cmd)
        try:
            subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
        except subprocess.CalledProcessError as e:
            print("An error occurred:", e)


    # Copy the ball image
    ball = sorted(glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_user_study/axis={ax}/valid/{sample_id}_src={src}_dst={dst}/n_step={n_frames}/ball/m_*.png"))
    assert len(ball) == int(n_frames)
    if no_f1:
        if use_offset:
            ball = ball[1:][start_offset:end_offset]
        else:
            ball = ball[1:]
    os.makedirs(f'./vids/axis={ax}/{src}_{dst}/ball/', exist_ok=True)
    for img in ball:
        os.system(f'cp {img} ./vids/axis={ax}/{src}_{dst}/ball/{img.split("/")[-1]}')

    if use_offset:
        start_num = start_offset
    else:
        start_num = 0
    cmd = f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/ball/m_%03d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/ball.mp4'
    try:
        subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
    except subprocess.CalledProcessError as e:
        print("An error occurred:", e)

    # Concatenate all videos vertically following the method order
    video_list = []
    for m in method:
        if os.path.exists(f'./vids/axis={ax}/{src}_{dst}/res_{m}.mp4'):
            if "difareli++" in m:
                video_list.append(f'./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4')
            else:
                video_list.append(f'./vids/axis={ax}/{src}_{dst}/res_{m}.mp4')
    # video_list.append(f'./vids/axis={ax}/{src}_{dst}/ball.mp4')
    
    num_videos = len(video_list)
    # Generate FFmpeg inputs and filter_complex dynamically
    input_files = " ".join(f"-i {path}" for path in video_list)
    filter_complex = "".join(f"[{i}:v:0]" for i in range(num_videos)) + f"hstack=inputs={num_videos}"

    # Output file
    output_file = f"./vids/axis={ax}/{src}_{dst}/res_all.mp4"

    # Construct the FFmpeg command
    command = f"ffmpeg {input_files} -filter_complex \"{filter_complex}\" -c:v libx264 -crf 17 -preset slow {output_file}"

    # Execute the command
    try:
        subprocess.run(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
    except subprocess.CalledProcessError as e:
        print("An error occurred:", e)

    # Create the reverse video of res_all.mp4, ball.mp4 and cond.mp4
    os.system(f'ffmpeg -i {output_file} -vf reverse ./vids/axis={ax}/{src}_{dst}/res_all_reverse.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/{m}/cond_reverse.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/ball.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/ball_reverse.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_reverse.mp4')

    # Time concatenation
    filter_cat = f'-filter_complex "[0:v][1:v]concat=n=2:v=1:a=0"'
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/res_all.mp4 -i ./vids/axis={ax}/{src}_{dst}/res_all_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/res_all_concat.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/ball.mp4 -i ./vids/axis={ax}/{src}_{dst}/ball_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/ball_concat.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/cond_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/{m}/cond_concat.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_concat.mp4')

    # Copy the res_all.mp4 and ball.mp4 to ./vids/all_outputs/ and rename them with {src}_{dst}_{ax}.mp4
    os.system(f'cp /data/mint/DPM_Dataset/ffhq_256_with_anno/ffhq_256/valid/{src} ./vids/all_outputs/res/{src}')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/res_all_concat.mp4 ./vids/all_outputs/res/{src}_{dst}_{ax}.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/ball_concat.mp4 ./vids/all_outputs/res/{src}_{dst}_{ax}_ball.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/{m}/cond_concat.mp4 ./vids/all_outputs/misc/{src}_{dst}_{ax}_cond.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_concat.mp4 ./vids/all_outputs/misc/{src}_{dst}_{ax}_res+cond.mp4')
# Out:
#   0%|          | 0/20 [00:00<?, ?it/s]
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/60208.jpg_62581.jpg/hou21_rotate_axis=1/res_frame_%04d.png':
#   Duration: 00:00:01.28, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x565234ba24c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x565234ba24c0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x565234ba24c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/60208.jpg_62581.jpg/res_hou21_rotate_axis=1.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   32 fps=0.0 q=-1.0 Lsize=      64kB time=00:00:01.20 bitrate= 435.4kbits/s speed=5.68x
# video:63kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.863412%
# [libx264 @ 0x565234ba24c0] frame I:1     Avg QP:18.15  size: 10792
# [libx264 @ 0x565234ba24c0] frame P:13    Avg QP:18.48  size:  3757
# [libx264 @ 0x565234ba24c0] frame B:18    Avg QP:20.90  size:   235
# [libx264 @ 0x565234ba24c0] consecutive B-frames: 21.9%  6.2%  9.4% 62.5%
# [libx264 @ 0x565234ba24c0] mb I  I16..4:  0.0% 71.1% 28.9%
# [libx264 @ 0x565234ba24c0] mb P  I16..4:  0.3% 10.9%  2.0%  P16..4: 54.6% 16.0%  9.7%  0.0%  0.0%    skip: 6.6%
# [libx264 @ 0x565234ba24c0] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 20.7%  0.9%  0.5%  direct: 5.5%  skip:72.3%  L0:18.5% L1:49.1% BI:32.4%
# [libx264 @ 0x565234ba24c0] 8x8 transform intra:78.6% inter:79.3%
# [libx264 @ 0x565234ba24c0] direct mvs  spatial:77.8% temporal:22.2%
# [libx264 @ 0x565234ba24c0] coded y,uvDC,uvAC intra: 95.9% 95.0% 75.9% inter: 29.2% 13.5% 2.8%
# [libx264 @ 0x565234ba24c0] i16 v,h,dc,p: 10%  0%  0% 90%
# [libx264 @ 0x565234ba24c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21%  5%  5%  7% 12% 18%  9% 14%  8%
# [libx264 @ 0x565234ba24c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13%  5%  5%  9% 15% 18% 11% 13% 10%
# [libx264 @ 0x565234ba24c0] i8c dc,h,v,p: 39% 14% 30% 17%
# [libx264 @ 0x565234ba24c0] Weighted P-Frames: Y:61.5% UV:0.0%
# [libx264 @ 0x565234ba24c0] ref P L0: 61.9% 21.2% 13.4%  1.4%  0.8%  1.1%  0.2%
# [libx264 @ 0x565234ba24c0] ref B L0: 96.6%  2.6%  0.7%  0.1%
# [libx264 @ 0x565234ba24c0] ref B L1: 98.3%  1.7%
# [libx264 @ 0x565234ba24c0] kb/s:383.22
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/60208.jpg_62581.jpg/hou22_rotate_axis=1/res_frame_%04d.png':
#   Duration: 00:00:01.28, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5561559144c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5561559144c0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x5561559144c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/60208.jpg_62581.jpg/res_hou22_rotate_axis=1.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   32 fps=0.0 q=-1.0 Lsize=      44kB time=00:00:01.20 bitrate= 299.1kbits/s speed=7.93x
# video:43kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.493138%
# [libx264 @ 0x5561559144c0] frame I:1     Avg QP:14.41  size: 22789
# [libx264 @ 0x5561559144c0] frame P:22    Avg QP:16.70  size:   877
# [libx264 @ 0x5561559144c0] frame B:9     Avg QP:21.49  size:   144
# [libx264 @ 0x5561559144c0] consecutive B-frames: 62.5%  0.0%  0.0% 37.5%
# [libx264 @ 0x5561559144c0] mb I  I16..4:  0.0% 76.2% 23.8%
# [libx264 @ 0x5561559144c0] mb P  I16..4:  0.0%  1.8%  0.1%  P16..4: 16.6%  2.4%  1.9%  0.0%  0.0%    skip:77.3%
# [libx264 @ 0x5561559144c0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  5.3%  0.0%  0.8%  direct: 4.3%  skip:89.6%  L0:20.5% L1:42.3% BI:37.2%
# [libx264 @ 0x5561559144c0] 8x8 transform intra:81.3% inter:75.6%
# [libx264 @ 0x5561559144c0] direct mvs  spatial:55.6% temporal:44.4%
# [libx264 @ 0x5561559144c0] coded y,uvDC,uvAC intra: 99.7% 99.7% 97.0% inter: 11.5% 12.1% 2.2%
# [libx264 @ 0x5561559144c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21%  9% 14%  6% 10% 12%  8% 10%  9%
# [libx264 @ 0x5561559144c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  9%  6% 11%  9% 19% 17% 13%  9%  8%
# [libx264 @ 0x5561559144c0] i8c dc,h,v,p: 47% 11% 20% 21%
# [libx264 @ 0x5561559144c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5561559144c0] ref P L0: 61.3% 33.5%  3.1%  1.0%  0.5%  0.6%
# [libx264 @ 0x5561559144c0] ref B L0: 92.7%  5.2%  2.1%
# [libx264 @ 0x5561559144c0] ref B L1: 95.9%  4.1%
# [libx264 @ 0x5561559144c0] kb/s:260.35
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/60208.jpg_62581.jpg/diffusionrig_rotate_axis=1_0.7sh/res_frame_%04d.png':
#   Duration: 00:00:01.28, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55d162ffb4c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d162ffb4c0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55d162ffb4c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/60208.jpg_62581.jpg/res_diffusionrig_rotate_axis=1_0.7sh.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   32 fps=0.0 q=-1.0 Lsize=      62kB time=00:00:01.20 bitrate= 423.1kbits/s speed=5.79x
# video:61kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.736598%
# [libx264 @ 0x55d162ffb4c0] frame I:1     Avg QP:18.32  size: 10534
# [libx264 @ 0x55d162ffb4c0] frame P:22    Avg QP:18.81  size:  2210
# [libx264 @ 0x55d162ffb4c0] frame B:9     Avg QP:20.08  size:   330
# [libx264 @ 0x55d162ffb4c0] consecutive B-frames: 62.5%  0.0%  0.0% 37.5%
# [libx264 @ 0x55d162ffb4c0] mb I  I16..4:  2.3% 55.9% 41.8%
# [libx264 @ 0x55d162ffb4c0] mb P  I16..4:  0.1%  3.5%  0.8%  P16..4: 52.0% 22.6% 12.1%  0.0%  0.0%    skip: 8.9%
# [libx264 @ 0x55d162ffb4c0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 28.0%  2.3%  0.5%  direct: 5.9%  skip:63.3%  L0:20.2% L1:42.1% BI:37.7%
# [libx264 @ 0x55d162ffb4c0] 8x8 transform intra:67.8% inter:69.3%
# [libx264 @ 0x55d162ffb4c0] direct mvs  spatial:55.6% temporal:44.4%
# [libx264 @ 0x55d162ffb4c0] coded y,uvDC,uvAC intra: 91.4% 88.7% 55.5% inter: 42.3% 38.2% 2.6%
# [libx264 @ 0x55d162ffb4c0] i16 v,h,dc,p:  0%  0%  0% 100%
# [libx264 @ 0x55d162ffb4c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 10%  2%  7% 11% 19% 11% 13%  9%
# [libx264 @ 0x55d162ffb4c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10%  4%  5%  7% 23% 20% 13% 11%  7%
# [libx264 @ 0x55d162ffb4c0] i8c dc,h,v,p: 37% 17% 24% 22%
# [libx264 @ 0x55d162ffb4c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55d162ffb4c0] ref P L0: 69.0% 27.5%  2.0%  0.6%  0.5%  0.3%
# [libx264 @ 0x55d162ffb4c0] ref B L0: 95.2%  3.4%  1.0%  0.5%
# [libx264 @ 0x55d162ffb4c0] ref B L1: 98.1%  1.9%
# [libx264 @ 0x55d162ffb4c0] kb/s:372.81
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/60208.jpg_62581.jpg/iclight_rotate_512x512_map_centered_axis1/res_frame_%04d.png':
#   Duration: 00:00:01.28, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x556a94c22880] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x556a94c22880] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x556a94c22880] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/60208.jpg_62581.jpg/res_iclight_rotate_512x512_map_centered_axis1.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   32 fps=0.0 q=-1.0 Lsize=      87kB time=00:00:01.20 bitrate= 591.5kbits/s speed=6.78x
# video:86kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.236093%
# [libx264 @ 0x556a94c22880] frame I:1     Avg QP:18.63  size: 18754
# [libx264 @ 0x556a94c22880] frame P:24    Avg QP:19.86  size:  2785
# [libx264 @ 0x556a94c22880] frame B:7     Avg QP:21.21  size:   282
# [libx264 @ 0x556a94c22880] consecutive B-frames: 68.8%  6.2%  0.0% 25.0%
# [libx264 @ 0x556a94c22880] mb I  I16..4:  4.7% 59.0% 36.3%
# [libx264 @ 0x556a94c22880] mb P  I16..4:  2.4%  4.0%  0.8%  P16..4: 66.5% 13.4% 10.4%  0.0%  0.0%    skip: 2.5%
# [libx264 @ 0x556a94c22880] mb B  I16..4:  0.1%  0.2%  0.0%  B16..8: 22.8%  2.3%  0.5%  direct: 7.8%  skip:66.2%  L0:23.1% L1:39.7% BI:37.2%
# [libx264 @ 0x556a94c22880] 8x8 transform intra:56.9% inter:76.4%
# [libx264 @ 0x556a94c22880] direct mvs  spatial:57.1% temporal:42.9%
# [libx264 @ 0x556a94c22880] coded y,uvDC,uvAC intra: 66.1% 71.1% 39.4% inter: 51.5% 51.2% 10.1%
# [libx264 @ 0x556a94c22880] i16 v,h,dc,p: 12%  4%  2% 81%
# [libx264 @ 0x556a94c22880] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 10%  9%  8% 15% 13% 13%  9%  7%
# [libx264 @ 0x556a94c22880] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10%  6%  7%  9% 20% 16% 12% 12%  8%
# [libx264 @ 0x556a94c22880] i8c dc,h,v,p: 48% 21% 20% 11%
# [libx264 @ 0x556a94c22880] Weighted P-Frames: Y:58.3% UV:41.7%
# [libx264 @ 0x556a94c22880] ref P L0: 55.8% 23.4% 18.1%  1.7%  0.7%  0.2%  0.1%
# [libx264 @ 0x556a94c22880] ref B L0: 91.0%  7.0%  2.0%
# [libx264 @ 0x556a94c22880] ref B L1: 99.5%  0.5%
# [libx264 @ 0x556a94c22880] kb/s:525.44
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/60208.jpg_62581.jpg/relipa_rotate_axis=1_0.6sh/res_frame_%04d.png':
#   Duration: 00:00:01.28, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x556f6594c4c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x556f6594c4c0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x556f6594c4c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/60208.jpg_62581.jpg/res_relipa_rotate_axis=1_0.6sh.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   32 fps=0.0 q=-1.0 Lsize=     113kB time=00:00:01.20 bitrate= 766.5kbits/s speed=4.54x
# video:112kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.021681%
# [libx264 @ 0x556f6594c4c0] frame I:1     Avg QP:19.30  size: 12665
# [libx264 @ 0x556f6594c4c0] frame P:15    Avg QP:20.50  size:  4887
# [libx264 @ 0x556f6594c4c0] frame B:16    Avg QP:22.74  size:  1747
# [libx264 @ 0x556f6594c4c0] consecutive B-frames: 28.1%  6.2% 28.1% 37.5%
# [libx264 @ 0x556f6594c4c0] mb I  I16..4:  2.0% 64.5% 33.6%
# [libx264 @ 0x556f6594c4c0] mb P  I16..4:  0.6% 13.1%  3.0%  P16..4: 39.8% 25.4% 14.0%  0.0%  0.0%    skip: 4.0%
# [libx264 @ 0x556f6594c4c0] mb B  I16..4:  0.1%  4.4%  0.7%  B16..8: 26.5% 10.3%  3.7%  direct:22.9%  skip:31.4%  L0:36.6% L1:36.7% BI:26.7%
# [libx264 @ 0x556f6594c4c0] 8x8 transform intra:76.4% inter:68.4%
# [libx264 @ 0x556f6594c4c0] direct mvs  spatial:87.5% temporal:12.5%
# [libx264 @ 0x556f6594c4c0] coded y,uvDC,uvAC intra: 93.2% 94.2% 66.2% inter: 54.4% 49.7% 5.3%
# [libx264 @ 0x556f6594c4c0] i16 v,h,dc,p: 23%  7%  0% 70%
# [libx264 @ 0x556f6594c4c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 19% 10%  4%  6% 12% 14% 11% 14% 10%
# [libx264 @ 0x556f6594c4c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12%  5%  5%  9% 17% 19% 11% 13%  9%
# [libx264 @ 0x556f6594c4c0] i8c dc,h,v,p: 43% 16% 19% 22%
# [libx264 @ 0x556f6594c4c0] Weighted P-Frames: Y:40.0% UV:26.7%
# [libx264 @ 0x556f6594c4c0] ref P L0: 64.0% 20.5% 11.3%  2.7%  0.6%  0.7%  0.1%
# [libx264 @ 0x556f6594c4c0] ref B L0: 82.0% 13.6%  3.3%  1.1%
# [libx264 @ 0x556f6594c4c0] ref B L1: 98.7%  1.3%
# [libx264 @ 0x556f6594c4c0] kb/s:683.56
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/60208.jpg_62581.jpg/ours_difareli_rotate_rot1_0.7sh_250t/res_frame_%04d.png':
#   Duration: 00:00:01.28, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5558bd05c880] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5558bd05c880] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x5558bd05c880] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/60208.jpg_62581.jpg/res_ours_difareli_rotate_rot1_0.7sh_250t.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   32 fps=0.0 q=-1.0 Lsize=      64kB time=00:00:01.20 bitrate= 436.4kbits/s speed=6.19x
# video:63kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.532679%
# [libx264 @ 0x5558bd05c880] frame I:1     Avg QP:17.02  size: 19952
# [libx264 @ 0x5558bd05c880] frame P:31    Avg QP:18.58  size:  1428
# [libx264 @ 0x5558bd05c880] mb I  I16..4:  0.8% 68.8% 30.5%
# [libx264 @ 0x5558bd05c880] mb P  I16..4:  0.0%  0.1%  0.0%  P16..4: 60.0%  7.3%  8.5%  0.0%  0.0%    skip:24.0%
# [libx264 @ 0x5558bd05c880] 8x8 transform intra:70.0% inter:74.4%
# [libx264 @ 0x5558bd05c880] coded y,uvDC,uvAC intra: 98.8% 97.4% 86.9% inter: 49.9% 34.3% 2.7%
# [libx264 @ 0x5558bd05c880] i16 v,h,dc,p:  0%  0%  0% 100%
# [libx264 @ 0x5558bd05c880] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26%  9%  8%  6% 10% 14%  6% 12%  9%
# [libx264 @ 0x5558bd05c880] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  9%  6% 10%  8% 16% 19% 11% 12% 10%
# [libx264 @ 0x5558bd05c880] i8c dc,h,v,p: 46% 13% 19% 22%
# [libx264 @ 0x5558bd05c880] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5558bd05c880] ref P L0: 68.0% 29.7%  1.6%  0.3%  0.2%  0.2%
# [libx264 @ 0x5558bd05c880] kb/s:385.38
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/60208.jpg_62581.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res_frame_%04d.png':
#   Duration: 00:00:01.28, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56033f0506c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56033f0506c0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x56033f0506c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/60208.jpg_62581.jpg/res_ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   32 fps=0.0 q=-1.0 Lsize=      74kB time=00:00:01.20 bitrate= 498.9kbits/s speed=5.76x
# video:73kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.392645%
# [libx264 @ 0x56033f0506c0] frame I:1     Avg QP:17.83  size: 19918
# [libx264 @ 0x56033f0506c0] frame P:28    Avg QP:18.98  size:  1901
# [libx264 @ 0x56033f0506c0] frame B:3     Avg QP:21.31  size:   159
# [libx264 @ 0x56033f0506c0] consecutive B-frames: 84.4%  6.2%  9.4%  0.0%
# [libx264 @ 0x56033f0506c0] mb I  I16..4:  0.4% 76.6% 23.0%
# [libx264 @ 0x56033f0506c0] mb P  I16..4:  0.0%  1.2%  0.0%  P16..4: 73.5%  8.9%  8.9%  0.0%  0.0%    skip: 7.5%
# [libx264 @ 0x56033f0506c0] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 22.4%  0.7%  0.1%  direct: 2.1%  skip:74.7%  L0:21.8% L1:39.2% BI:39.0%
# [libx264 @ 0x56033f0506c0] 8x8 transform intra:82.2% inter:79.0%
# [libx264 @ 0x56033f0506c0] direct mvs  spatial:33.3% temporal:66.7%
# [libx264 @ 0x56033f0506c0] coded y,uvDC,uvAC intra: 99.6% 97.4% 74.0% inter: 58.9% 48.9% 3.5%
# [libx264 @ 0x56033f0506c0] i16 v,h,dc,p:  0%  0%  0% 100%
# [libx264 @ 0x56033f0506c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18%  8% 12%  6% 11% 14%  9% 12% 11%
# [libx264 @ 0x56033f0506c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  9%  5% 12%  9% 15% 17% 13% 10%  9%
# [libx264 @ 0x56033f0506c0] i8c dc,h,v,p: 43% 13% 22% 22%
# [libx264 @ 0x56033f0506c0] Weighted P-Frames: Y:14.3% UV:3.6%
# [libx264 @ 0x56033f0506c0] ref P L0: 58.8% 35.3%  3.2%  0.9%  0.7%  1.1%  0.0%
# [libx264 @ 0x56033f0506c0] ref B L0: 98.2%  1.8%
# [libx264 @ 0x56033f0506c0] kb/s:441.78
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/60208.jpg_62581.jpg/res_all.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:01.33, start: 0.000000, bitrate: 3248 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 3244 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5592efeacf80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5592efeacf80] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5592efeacf80] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/60208.jpg_62581.jpg/res_all_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   32 fps=0.0 q=-1.0 Lsize=     288kB time=00:00:01.20 bitrate=1953.4kbits/s speed=2.21x
# video:287kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.360205%
# [libx264 @ 0x5592efeacf80] frame I:1     Avg QP:23.10  size: 70872
# [libx264 @ 0x5592efeacf80] frame P:28    Avg QP:25.25  size:  7805
# [libx264 @ 0x5592efeacf80] frame B:3     Avg QP:28.89  size:  1297
# [libx264 @ 0x5592efeacf80] consecutive B-frames: 81.2% 18.8%  0.0%  0.0%
# [libx264 @ 0x5592efeacf80] mb I  I16..4:  8.3% 66.1% 25.6%
# [libx264 @ 0x5592efeacf80] mb P  I16..4:  0.9%  3.0%  0.5%  P16..4: 45.1%  9.2%  6.4%  0.0%  0.0%    skip:34.8%
# [libx264 @ 0x5592efeacf80] mb B  I16..4:  0.1%  1.1%  0.1%  B16..8: 13.4%  1.2%  0.5%  direct: 2.4%  skip:81.2%  L0:29.8% L1:61.7% BI: 8.4%
# [libx264 @ 0x5592efeacf80] 8x8 transform intra:67.3% inter:70.3%
# [libx264 @ 0x5592efeacf80] coded y,uvDC,uvAC intra: 70.2% 77.7% 36.1% inter: 31.3% 29.0% 0.6%
# [libx264 @ 0x5592efeacf80] i16 v,h,dc,p: 33%  8%  3% 57%
# [libx264 @ 0x5592efeacf80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 10% 11%  7% 10% 13%  8% 12%  7%
# [libx264 @ 0x5592efeacf80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24%  9% 13%  6% 12% 15%  7%  9%  5%
# [libx264 @ 0x5592efeacf80] i8c dc,h,v,p: 48% 14% 28% 10%
# [libx264 @ 0x5592efeacf80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5592efeacf80] ref P L0: 58.3% 38.0%  2.8%  1.0%
# [libx264 @ 0x5592efeacf80] ref B L0: 95.0%  5.0%
# [libx264 @ 0x5592efeacf80] kb/s:1759.86
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/60208.jpg_62581.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:01.33, start: 0.000000, bitrate: 154 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 146 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5631666253c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5631666253c0] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x5631666253c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/60208.jpg_62581.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x512, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   32 fps=0.0 q=-1.0 Lsize=      24kB time=00:00:01.20 bitrate= 165.7kbits/s speed=9.79x
# video:23kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.154163%
# [libx264 @ 0x5631666253c0] frame I:1     Avg QP:21.85  size:  2851
# [libx264 @ 0x5631666253c0] frame P:10    Avg QP:25.88  size:  1346
# [libx264 @ 0x5631666253c0] frame B:21    Avg QP:22.07  size:   324
# [libx264 @ 0x5631666253c0] consecutive B-frames: 12.5%  0.0%  0.0% 87.5%
# [libx264 @ 0x5631666253c0] mb I  I16..4: 13.7% 66.6% 19.7%
# [libx264 @ 0x5631666253c0] mb P  I16..4:  1.4%  6.7%  3.3%  P16..4:  9.8%  3.8%  1.3%  0.0%  0.0%    skip:73.7%
# [libx264 @ 0x5631666253c0] mb B  I16..4:  0.1%  0.1%  0.2%  B16..8:  6.3%  2.3%  0.8%  direct: 0.4%  skip:89.9%  L0:52.5% L1:43.2% BI: 4.3%
# [libx264 @ 0x5631666253c0] 8x8 transform intra:61.4% inter:34.7%
# [libx264 @ 0x5631666253c0] coded y,uvDC,uvAC intra: 33.7% 12.4% 0.0% inter: 2.8% 0.5% 0.0%
# [libx264 @ 0x5631666253c0] i16 v,h,dc,p: 51%  7% 12% 31%
# [libx264 @ 0x5631666253c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 12% 31%  2%  4%  7%  3%  4%  2%
# [libx264 @ 0x5631666253c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 18% 23%  4%  4%  5%  4%  5%  2%
# [libx264 @ 0x5631666253c0] i8c dc,h,v,p: 82%  6% 11%  0%
# [libx264 @ 0x5631666253c0] Weighted P-Frames: Y:30.0% UV:0.0%
# [libx264 @ 0x5631666253c0] ref P L0: 59.7% 19.5% 12.5%  5.9%  2.4%
# [libx264 @ 0x5631666253c0] ref B L0: 87.7% 10.9%  1.3%
# [libx264 @ 0x5631666253c0] ref B L1: 95.2%  4.8%
# [libx264 @ 0x5631666253c0] kb/s:138.70
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/60208.jpg_62581.jpg/ball.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:01.33, start: 0.000000, bitrate: 116 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 109 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55a47a38e540] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55a47a38e540] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55a47a38e540] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/60208.jpg_62581.jpg/ball_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
# ...
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/61234.jpg_64857.jpg/ball.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:01.33, start: 0.000000, bitrate: 116 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 109 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/61234.jpg_64857.jpg/ball_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:01.33, start: 0.000000, bitrate: 87 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 80 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f16bd5ce00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f16bd5ce00] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55f16bd5ce00] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/61234.jpg_64857.jpg/ball_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   64 fps=0.0 q=-1.0 Lsize=      26kB time=00:00:02.54 bitrate=  82.3kbits/s speed=19.1x
# video:24kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.530330%
# [libx264 @ 0x55f16bd5ce00] frame I:1     Avg QP:23.46  size:  1859
# [libx264 @ 0x55f16bd5ce00] frame P:22    Avg QP:25.11  size:   741
# [libx264 @ 0x55f16bd5ce00] frame B:41    Avg QP:18.24  size:   139
# [libx264 @ 0x55f16bd5ce00] consecutive B-frames:  1.6% 34.4% 14.1% 50.0%
# [libx264 @ 0x55f16bd5ce00] mb I  I16..4: 44.9% 32.4% 22.7%
# [libx264 @ 0x55f16bd5ce00] mb P  I16..4: 15.5%  5.9%  1.3%  P16..4: 33.9%  6.9%  2.0%  0.0%  0.0%    skip:34.5%
# [libx264 @ 0x55f16bd5ce00] mb B  I16..4:  0.8%  0.2%  0.0%  B16..8: 22.6%  1.3%  0.1%  direct: 0.1%  skip:74.9%  L0:41.0% L1:51.8% BI: 7.2%
# [libx264 @ 0x55f16bd5ce00] 8x8 transform intra:26.4% inter:66.5%
# [libx264 @ 0x55f16bd5ce00] coded y,uvDC,uvAC intra: 10.4% 14.7% 0.0% inter: 3.9% 1.6% 0.0%
# [libx264 @ 0x55f16bd5ce00] i16 v,h,dc,p: 13%  9%  2% 77%
# [libx264 @ 0x55f16bd5ce00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 14% 32%  3%  9%  9%  7%  6%  1%
# [libx264 @ 0x55f16bd5ce00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 15% 26%  4%  9%  8%  7%  4%  1%
# [libx264 @ 0x55f16bd5ce00] i8c dc,h,v,p: 71%  9% 19%  0%
# [libx264 @ 0x55f16bd5ce00] Weighted P-Frames: Y:22.7% UV:0.0%
# [libx264 @ 0x55f16bd5ce00] ref P L0: 64.3% 11.0% 17.5%  6.5%  0.7%
# [libx264 @ 0x55f16bd5ce00] ref B L0: 91.6%  7.4%  0.9%
# [libx264 @ 0x55f16bd5ce00] ref B L1: 99.0%  1.0%
# [libx264 @ 0x55f16bd5ce00] kb/s:71.57
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:01.33, start: 0.000000, bitrate: 142 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 135 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:01.33, start: 0.000000, bitrate: 145 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 138 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55c1e7d04e80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55c1e7d04e80] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x55c1e7d04e80] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x512, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   64 fps=0.0 q=-1.0 Lsize=      41kB time=00:00:02.54 bitrate= 133.6kbits/s speed=  17x
# video:40kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.904911%
# [libx264 @ 0x55c1e7d04e80] frame I:1     Avg QP:20.33  size:  2709
# [libx264 @ 0x55c1e7d04e80] frame P:21    Avg QP:24.73  size:  1231
# [libx264 @ 0x55c1e7d04e80] frame B:42    Avg QP:23.25  size:   276
# [libx264 @ 0x55c1e7d04e80] consecutive B-frames:  9.4%  6.2%  9.4% 75.0%
# [libx264 @ 0x55c1e7d04e80] mb I  I16..4: 10.5% 72.9% 16.6%
# [libx264 @ 0x55c1e7d04e80] mb P  I16..4:  1.7%  6.0%  2.4%  P16..4: 10.5%  4.7%  1.5%  0.0%  0.0%    skip:73.2%
# [libx264 @ 0x55c1e7d04e80] mb B  I16..4:  0.2%  0.1%  0.2%  B16..8:  7.6%  1.5%  0.5%  direct: 0.4%  skip:89.4%  L0:43.6% L1:50.6% BI: 5.8%
# [libx264 @ 0x55c1e7d04e80] 8x8 transform intra:61.3% inter:52.4%
# [libx264 @ 0x55c1e7d04e80] coded y,uvDC,uvAC intra: 38.2% 8.1% 0.0% inter: 3.0% 0.6% 0.0%
# [libx264 @ 0x55c1e7d04e80] i16 v,h,dc,p: 41%  7%  8% 44%
# [libx264 @ 0x55c1e7d04e80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 17% 20%  4%  6%  6%  6%  6%  4%
# [libx264 @ 0x55c1e7d04e80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 18% 22%  4%  5%  6%  5%  4%  3%
# [libx264 @ 0x55c1e7d04e80] i8c dc,h,v,p: 78%  7% 14%  0%
# [libx264 @ 0x55c1e7d04e80] Weighted P-Frames: Y:33.3% UV:0.0%
# [libx264 @ 0x55c1e7d04e80] ref P L0: 60.6% 13.3% 17.3%  6.5%  2.3%
# [libx264 @ 0x55c1e7d04e80] ref B L0: 85.1% 12.0%  2.9%
# [libx264 @ 0x55c1e7d04e80] ref B L1: 96.9%  3.1%
# [libx264 @ 0x55c1e7d04e80] kb/s:120.47
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:01.33, start: 0.000000, bitrate: 519 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 513 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:01.33, start: 0.000000, bitrate: 295 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 288 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x562b557474c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x562b557474c0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x562b557474c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 384x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   64 fps=0.0 q=-1.0 Lsize=      88kB time=00:00:02.54 bitrate= 283.5kbits/s speed=12.8x
# video:87kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.499803%
# [libx264 @ 0x562b557474c0] frame I:1     Avg QP:22.81  size:  8954
# [libx264 @ 0x562b557474c0] frame P:51    Avg QP:24.95  size:  1480
# [libx264 @ 0x562b557474c0] frame B:12    Avg QP:28.47  size:   302
# [libx264 @ 0x562b557474c0] consecutive B-frames: 68.8% 18.8%  0.0% 12.5%
# [libx264 @ 0x562b557474c0] mb I  I16..4: 20.3% 49.2% 30.5%
# [libx264 @ 0x562b557474c0] mb P  I16..4:  1.2%  2.8%  0.5%  P16..4: 39.6%  9.5%  5.1%  0.0%  0.0%    skip:41.1%
# [libx264 @ 0x562b557474c0] mb B  I16..4:  0.1%  0.3%  0.2%  B16..8: 17.6%  1.0%  0.9%  direct: 2.8%  skip:77.1%  L0:32.8% L1:63.1% BI: 4.1%
# [libx264 @ 0x562b557474c0] 8x8 transform intra:57.4% inter:69.3%
# [libx264 @ 0x562b557474c0] coded y,uvDC,uvAC intra: 52.0% 47.0% 11.9% inter: 24.7% 15.9% 0.4%
# [libx264 @ 0x562b557474c0] i16 v,h,dc,p: 75%  2%  9% 15%
# [libx264 @ 0x562b557474c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32%  9% 23%  4%  6% 10%  5%  6%  4%
# [libx264 @ 0x562b557474c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 11% 23%  6%  7%  9%  6%  6%  5%
# [libx264 @ 0x562b557474c0] i8c dc,h,v,p: 65%  9% 22%  4%
# [libx264 @ 0x562b557474c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x562b557474c0] ref P L0: 61.3% 33.9%  2.9%  1.9%
# [libx264 @ 0x562b557474c0] ref B L0: 88.3%  8.5%  3.2%
# [libx264 @ 0x562b557474c0] ref B L1: 98.9%  1.1%
# [libx264 @ 0x562b557474c0] kb/s:264.17
# 100%|██████████| 20/20 [00:44<00:00,  2.23s/it]
