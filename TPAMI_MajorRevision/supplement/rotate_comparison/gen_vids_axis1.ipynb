# %%
import json, os, glob, tqdm
from PIL import Image
import numpy as np
import subprocess

def sort_by_frame(path_list):
    frame_anno = []
    for p in path_list:
        frame_idx = os.path.splitext(p.split('/')[-1].split('_')[-1])[0][5:]   # 0-4 is "frame", so we used [5:] here
        frame_anno.append(int(frame_idx))
    sorted_idx = np.argsort(frame_anno)
    sorted_path_list = []
    for idx in sorted_idx:
      sorted_path_list.append(path_list[idx])
    return sorted_path_list

# %% [markdown]
# # FFHQ: RotateSH_axis1.json

# %%
ax = 1

# sample_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/experiment_scripts/TPAMI/sample_json/TPAMI_MajorRevision/rotateSH_axis1.json", "r"))
sample_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/experiment_scripts/TPAMI/sample_json/TPAMI_MajorRevision/website.json", "r"))

method = ["hou21_rotate_axis=1", "hou22_rotate_axis=1", "diffusionrig_rotate_axis=1_0.7sh", "iclight_rotate_512x512_map_centered_axis1", "relipa_rotate_axis=1_0.6sh", "ours_difareli_rotate_rot1_0.7sh_250t", "ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh"]
# meta_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/visualize_scripts/TPAMI/MajorRevision/figure/ffhq/rotateSH_axis1.json", "r"))
meta_dat = json.load(open("./for_rotate1_website.json", "r"))


os.makedirs("./vids/", exist_ok=True)
os.makedirs(f'./vids/all_outputs/res/', exist_ok=True)
os.makedirs(f'./vids/all_outputs/misc/', exist_ok=True)

no_f1 = True
focus_src = [f'{f}.jpg' for f in [62848, 60208, 69757, 61234]]
use_offset = True
start_offset = 30
end_offset = 210

target_n_frames = 60

for sample_id, sample in tqdm.tqdm(sample_dat['pair'].items()):
    src = sample['src']
    dst = sample['dst']
    if src not in focus_src:
        continue
    print(src, dst)
    for m in method:
        img_dir = meta_dat[m]['img_dir']
        n_frames = meta_dat[m]['n_frame']
        itp_method = meta_dat[m]['itp_method']
        diff_step = meta_dat[m]['diff_step']
        n_frame_tmp = meta_dat[m]['n_frame']
        
        os.makedirs(f'./vids/axis={ax}/{src}_{dst}/{m}/', exist_ok=True)
        if "hou21" in m or "hou22" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            print(img_path)
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
            idx = np.linspace(0, len(relit)-1, target_n_frames, dtype=int)
            relit = [relit[i] for i in idx]
            
        elif "iclight" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
            idx = np.linspace(0, len(relit)-1, target_n_frames, dtype=int)
            relit = [relit[i] for i in idx]
        elif m == "diffusionrig_rotate_axis=1_0.7sh":
            img_path = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/n_frames={n_frame_tmp}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:]
            idx = np.linspace(0, len(relit)-1, target_n_frames, dtype=int)
            relit = [relit[i] for i in idx]
            
        elif m == "relipa_rotate_axis=1_0.6sh":
            img_path = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/gs=4.5_ds=25/n_frames={n_frame_tmp}/256/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:]
            idx = np.linspace(0, len(relit)-1, target_n_frames, dtype=int)
            relit = [relit[i] for i in idx]
        elif "difareli++" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:][start_offset:end_offset]
                shadow = sort_by_frame(glob.glob(f'{img_path}/dst_shadm_shad_f*.png'))[1:][start_offset:end_offset]
                render = sort_by_frame(glob.glob(f'{img_path}/dst_ren_f*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
                shadow = sort_by_frame(glob.glob(f'{img_path}/dst_shadm_shad_f*.png'))[1:]
                render = sort_by_frame(glob.glob(f'{img_path}/dst_ren_f*.png'))[1:]
            idx = np.linspace(0, len(relit)-1, target_n_frames, dtype=int)
            relit = [relit[i] for i in idx]
            shadow = [shadow[i] for i in idx]
            render = [render[i] for i in idx]
            for _, (s, r) in enumerate(zip(shadow, render)):
                i = int(s.split('/')[-1].split('frame')[-1].split('.')[0])
                assert i == int(r.split('/')[-1].split('frame')[-1].split('.')[0])
                os.system(f'cp {s} ./vids/axis={ax}/{src}_{dst}/{m}/dst_shadm_shad_frame_{i:04d}.png')
                os.system(f'cp {r} ./vids/axis={ax}/{src}_{dst}/{m}/dst_ren_frame_{i:04d}.png')

            assert len(relit) == len(shadow) == len(render)
            for j in range(len(relit)):
                frame_id = int(relit[j].split('/')[-1].split('frame')[-1].split('.')[0])
                r_tmp = np.array(Image.open(relit[j]))
                h, w, _ = r_tmp.shape
                s_tmp = np.array(Image.open(shadow[j]).resize((h//2, w//2)))
                ren_tmp = np.array(Image.open(render[j]).resize((h//2, w//2)))
                
                out_comb = np.concatenate((r_tmp, np.concatenate((ren_tmp, s_tmp), axis=0)), axis=1)
                Image.fromarray(out_comb).save(f'./vids/axis={ax}/{src}_{dst}/{m}/res+cond_frame_{frame_id:04d}.png')
             
            if use_offset:   
                start_num = start_offset
            else:
                start_num = 0
            cmds = [f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/{m}/dst_shadm_shad_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/shadow.mp4',
                    f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/{m}/dst_ren_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/render.mp4',
                    # Vertical stack them (render on top of shadow)
                    f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/render.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/shadow.mp4 -filter_complex vstack ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4',
                    f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4'
            ]
            for c in cmds:
                try:
                    subprocess.run(c, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
                except subprocess.CalledProcessError as e:
                    print("An error occurred:", e)
        
        
            
        elif "difareli" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
            idx = np.linspace(0, len(relit)-1, target_n_frames, dtype=int)
            relit = [relit[i] for i in idx]
        
        if len(relit) == 0:
            # Create 0 images for mockup and match the number of frames
            for i in range(1, int(n_frames)):
                img = Image.new('RGB', (256, 256), color='black')
                img.save(f'./vids/axis={ax}/{src}_{dst}/{m}/res_frame_{i:04d}.png')
            continue
        
        os.makedirs(f'./vids/axis={ax}/{src}_{dst}/{m}/', exist_ok=True)
        # Copy all images to a new folder
        for img in relit:
            i = int(img.split('/')[-1].split('frame')[-1].split('.')[0])
            os.system(f'cp {img} ./vids/axis={ax}/{src}_{dst}/{m}/res_frame_{i:04d}.png')
        
        #NOTE: Generate video low compression with 24 fps
        if use_offset:
            start_num = start_offset
        else:
            start_num = 0
        cmd = f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/{m}/res_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/res_{m}.mp4'
        os.system(cmd)
        try:
            subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
        except subprocess.CalledProcessError as e:
            print("An error occurred:", e)


    # Copy the ball image
    ball = sorted(glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_website/axis={ax}/valid/{sample_id}_src={src}_dst={dst}/n_step={n_frames}/ball/m_*.png"))
    print(len(ball), n_frames)
    assert len(ball) == int(n_frames)
    if no_f1:
        if use_offset:
            ball = ball[1:][start_offset:end_offset]
        else:
            ball = ball[1:]
        idx = np.linspace(0, len(ball)-1, target_n_frames, dtype=int)
        ball = [ball[i] for i in idx]
    os.makedirs(f'./vids/axis={ax}/{src}_{dst}/ball/', exist_ok=True)
    for img in ball:
        os.system(f'cp {img} ./vids/axis={ax}/{src}_{dst}/ball/{img.split("/")[-1]}')

    if use_offset:
        start_num = start_offset
    else:
        start_num = 0
    cmd = f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/ball/m_%03d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/ball.mp4'
    try:
        subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
    except subprocess.CalledProcessError as e:
        print("An error occurred:", e)

    # Concatenate all videos vertically following the method order
    video_list = []
    for m in method:
        if os.path.exists(f'./vids/axis={ax}/{src}_{dst}/res_{m}.mp4'):
            if "difareli++" in m:
                video_list.append(f'./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4')
            else:
                video_list.append(f'./vids/axis={ax}/{src}_{dst}/res_{m}.mp4')
    # video_list.append(f'./vids/axis={ax}/{src}_{dst}/ball.mp4')
    
    num_videos = len(video_list)
    # Generate FFmpeg inputs and filter_complex dynamically
    input_files = " ".join(f"-i {path}" for path in video_list)
    filter_complex = "".join(f"[{i}:v:0]" for i in range(num_videos)) + f"hstack=inputs={num_videos}"

    # Output file
    output_file = f"./vids/axis={ax}/{src}_{dst}/res_all.mp4"

    # Construct the FFmpeg command
    command = f"ffmpeg {input_files} -filter_complex \"{filter_complex}\" -c:v libx264 -crf 17 -preset slow {output_file}"

    # Execute the command
    try:
        subprocess.run(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
    except subprocess.CalledProcessError as e:
        print("An error occurred:", e)

    # Create the reverse video of res_all.mp4, ball.mp4 and cond.mp4
    os.system(f'ffmpeg -i {output_file} -vf reverse ./vids/axis={ax}/{src}_{dst}/res_all_reverse.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/{m}/cond_reverse.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/ball.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/ball_reverse.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_reverse.mp4')

    # Time concatenation
    filter_cat = f'-filter_complex "[0:v][1:v]concat=n=2:v=1:a=0"'
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/res_all.mp4 -i ./vids/axis={ax}/{src}_{dst}/res_all_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/res_all_concat.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/ball.mp4 -i ./vids/axis={ax}/{src}_{dst}/ball_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/ball_concat.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/cond_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/{m}/cond_concat.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_concat.mp4')

    # Copy the res_all.mp4 and ball.mp4 to ./vids/all_outputs/ and rename them with {src}_{dst}_{ax}.mp4
    os.system(f'cp /data/mint/DPM_Dataset/ffhq_256_with_anno/ffhq_256/valid/{src} ./vids/all_outputs/res/{src}')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/res_all_concat.mp4 ./vids/all_outputs/res/{src}_{dst}_{ax}.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/ball_concat.mp4 ./vids/all_outputs/res/{src}_{dst}_{ax}_ball.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/{m}/cond_concat.mp4 ./vids/all_outputs/misc/{src}_{dst}_{ax}_cond.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_concat.mp4 ./vids/all_outputs/misc/{src}_{dst}_{ax}_res+cond.mp4')
# Out:
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/62848.jpg_66729.jpg/iclight_rotate_512x512_map_centered_axis1/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5600925d5380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5600925d5380] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x5600925d5380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_iclight_rotate_512x512_map_centered_axis1.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=       9kB time=00:00:00.00 bitrate=867753.1kbits/s speed=0.00108x
# video:8kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 10.335300%
# [libx264 @ 0x5600925d5380] frame I:1     Avg QP:22.71  size:  7274
# [libx264 @ 0x5600925d5380] mb I  I16..4: 23.0% 56.2% 20.7%
# [libx264 @ 0x5600925d5380] 8x8 transform intra:56.2%
# [libx264 @ 0x5600925d5380] coded y,uvDC,uvAC intra: 65.1% 72.7% 48.8%
# [libx264 @ 0x5600925d5380] i16 v,h,dc,p:  2% 14%  0% 85%
# [libx264 @ 0x5600925d5380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8% 23%  6%  6% 12% 11% 15%  7% 12%
# [libx264 @ 0x5600925d5380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  6% 18%  4%  7% 15% 13% 15%  8% 13%
# [libx264 @ 0x5600925d5380] i8c dc,h,v,p: 41% 20% 16% 23%
# [libx264 @ 0x5600925d5380] kb/s:1396.61
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/62848.jpg_66729.jpg/relipa_rotate_axis=1_0.6sh/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5585061c8080] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5585061c8080] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x5585061c8080] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_relipa_rotate_axis=1_0.6sh.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=       7kB time=00:00:00.00 bitrate=696790.1kbits/s speed=0.0011x
# video:6kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 13.206034%
# [libx264 @ 0x5585061c8080] frame I:1     Avg QP:20.58  size:  5543
# [libx264 @ 0x5585061c8080] mb I  I16..4: 10.5% 66.0% 23.4%
# [libx264 @ 0x5585061c8080] 8x8 transform intra:66.0%
# [libx264 @ 0x5585061c8080] coded y,uvDC,uvAC intra: 75.1% 71.1% 46.5%
# [libx264 @ 0x5585061c8080] i16 v,h,dc,p: 33% 44% 11% 11%
# [libx264 @ 0x5585061c8080] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10%  8%  9%  6% 13% 17% 12% 12% 11%
# [libx264 @ 0x5585061c8080] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14%  5%  4% 17% 14% 15%  9% 13%  9%
# [libx264 @ 0x5585061c8080] i8c dc,h,v,p: 35% 23% 17% 24%
# [libx264 @ 0x5585061c8080] kb/s:1064.26
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/62848.jpg_66729.jpg/ours_difareli_rotate_rot1_0.7sh_250t/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5588ffc48380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5588ffc48380] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x5588ffc48380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_ours_difareli_rotate_rot1_0.7sh_250t.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=       9kB time=00:00:00.00 bitrate=895209.9kbits/s speed=0.00106x
# video:8kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 9.986652%
# [libx264 @ 0x5588ffc48380] frame I:1     Avg QP:20.79  size:  7552
# [libx264 @ 0x5588ffc48380] mb I  I16..4:  3.5% 70.3% 26.2%
# [libx264 @ 0x5588ffc48380] 8x8 transform intra:70.3%
# [libx264 @ 0x5588ffc48380] coded y,uvDC,uvAC intra: 83.5% 72.7% 48.0%
# [libx264 @ 0x5588ffc48380] i16 v,h,dc,p: 44% 22% 11% 22%
# [libx264 @ 0x5588ffc48380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11%  8% 12% 11% 12% 15%  9% 11% 11%
# [libx264 @ 0x5588ffc48380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7%  7%  6% 10% 15% 17% 14% 13% 12%
# [libx264 @ 0x5588ffc48380] i8c dc,h,v,p: 47% 13% 15% 25%
# [libx264 @ 0x5588ffc48380] kb/s:1449.98
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/62848.jpg_66729.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55d645aab240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d645aab240] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55d645aab240] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=       8kB time=00:00:00.00 bitrate=807111.1kbits/s speed=0.00174x
# video:7kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 11.198803%
# [libx264 @ 0x55d645aab240] frame I:1     Avg QP:20.49  size:  6660
# [libx264 @ 0x55d645aab240] mb I  I16..4:  9.0% 75.4% 15.6%
# [libx264 @ 0x55d645aab240] 8x8 transform intra:75.4%
# [libx264 @ 0x55d645aab240] coded y,uvDC,uvAC intra: 91.6% 69.5% 37.9%
# [libx264 @ 0x55d645aab240] i16 v,h,dc,p: 22% 65%  4%  9%
# [libx264 @ 0x55d645aab240] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10%  9%  8%  8% 13% 16% 12% 13% 12%
# [libx264 @ 0x55d645aab240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  6%  5%  2% 11% 14% 20% 16% 13% 13%
# [libx264 @ 0x55d645aab240] i8c dc,h,v,p: 37% 22% 18% 23%
# [libx264 @ 0x55d645aab240] kb/s:1278.72
# 400 400
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/res_all.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 8940 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 8854 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55feaba9b200] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55feaba9b200] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x55feaba9b200] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_all_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=28.0 Lsize=      22kB time=00:00:00.00 bitrate=2227555.6kbits/s speed=0.00112x
# video:21kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.787216%
# [libx264 @ 0x55feaba9b200] frame I:1     Avg QP:26.91  size: 21042
# [libx264 @ 0x55feaba9b200] mb I  I16..4: 14.5% 65.1% 20.5%
# [libx264 @ 0x55feaba9b200] 8x8 transform intra:65.1%
# [libx264 @ 0x55feaba9b200] coded y,uvDC,uvAC intra: 55.0% 56.7% 13.5%
# [libx264 @ 0x55feaba9b200] i16 v,h,dc,p: 37% 23%  9% 30%
# [libx264 @ 0x55feaba9b200] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 15% 15%  6%  7% 11%  7%  7%  6%
# [libx264 @ 0x55feaba9b200] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 18% 10%  6%  9% 11%  8%  9%  7%
# [libx264 @ 0x55feaba9b200] i8c dc,h,v,p: 53% 16% 23%  8%
# [libx264 @ 0x55feaba9b200] kb/s:4040.06
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 699 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 547 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x56364d807380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56364d807380] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x56364d807380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x512, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=28.0 Lsize=       4kB time=00:00:00.00 bitrate=358913.6kbits/s speed=0.00108x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 29.277838%
# [libx264 @ 0x56364d807380] frame I:1     Avg QP:26.76  size:  2121
# [libx264 @ 0x56364d807380] mb I  I16..4: 11.7% 70.9% 17.4%
# [libx264 @ 0x56364d807380] 8x8 transform intra:70.9%
# [libx264 @ 0x56364d807380] coded y,uvDC,uvAC intra: 16.0% 3.1% 0.0%
# [libx264 @ 0x56364d807380] i16 v,h,dc,p: 67%  2% 28%  3%
# [libx264 @ 0x56364d807380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 51%  9% 30%  1%  3%  3%  2%  1%  1%
# [libx264 @ 0x56364d807380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 39% 16% 20%  5%  3%  4%  5%  5%  3%
# [libx264 @ 0x56364d807380] i8c dc,h,v,p: 92%  4%  4%  0%
# [libx264 @ 0x56364d807380] kb/s:407.23
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/ball.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 598 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 445 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x562395f5c780] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x562395f5c780] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x562395f5c780] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/ball_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=28.0 Lsize=       3kB time=00:00:00.00 bitrate=263111.1kbits/s speed=0.00111x
# video:2kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 44.703964%
# [libx264 @ 0x562395f5c780] frame I:1     Avg QP:25.50  size:  1152
# [libx264 @ 0x562395f5c780] mb I  I16..4: 54.3% 29.3% 16.4%
# [libx264 @ 0x562395f5c780] 8x8 transform intra:29.3%
# [libx264 @ 0x562395f5c780] coded y,uvDC,uvAC intra: 15.5% 9.4% 0.0%
# [libx264 @ 0x562395f5c780] i16 v,h,dc,p:  2% 12%  4% 82%
# [libx264 @ 0x562395f5c780] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  6% 35% 36%  1%  4%  5% 13%  0%  1%
# [libx264 @ 0x562395f5c780] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 24% 43%  5%  1%  4%  3%  3%  3%
# [libx264 @ 0x562395f5c780] i8c dc,h,v,p: 73% 16% 11%  0%
# [libx264 @ 0x562395f5c780] kb/s:221.18
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 1844 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 1700 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5590ca754d40] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5590ca754d40] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x5590ca754d40] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 384x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=28.0 Lsize=       5kB time=00:00:00.00 bitrate=496592.6kbits/s speed=0.0015x
# video:4kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 19.571938%
# [libx264 @ 0x5590ca754d40] frame I:1     Avg QP:26.67  size:  3516
# [libx264 @ 0x5590ca754d40] mb I  I16..4: 14.1% 65.6% 20.3%
# [libx264 @ 0x5590ca754d40] 8x8 transform intra:65.6%
# [libx264 @ 0x5590ca754d40] coded y,uvDC,uvAC intra: 46.6% 37.2% 6.0%
# [libx264 @ 0x5590ca754d40] i16 v,h,dc,p: 43% 20% 28%  9%
# [libx264 @ 0x5590ca754d40] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 11% 16%  4%  7%  9%  6%  5%  5%
# [libx264 @ 0x5590ca754d40] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 14% 17%  7%  8% 11%  5%  6%  7%
# [libx264 @ 0x5590ca754d40] i8c dc,h,v,p: 66% 12% 16%  6%
# [libx264 @ 0x5590ca754d40] kb/s:675.07
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/res_all.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 8940 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 8854 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/res_all_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 4296 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 4172 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x5643855078c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5643855078c0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5643855078c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_all_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    2 fps=0.0 q=-1.0 Lsize=      27kB time=00:00:00.04 bitrate=5253.4kbits/s speed=0.538x
# video:26kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.203584%
# [libx264 @ 0x5643855078c0] frame I:1     Avg QP:25.84  size: 24847
# [libx264 @ 0x5643855078c0] frame P:1     Avg QP:26.95  size:  1028
# [libx264 @ 0x5643855078c0] mb I  I16..4: 15.4% 61.6% 23.0%
# [libx264 @ 0x5643855078c0] mb P  I16..4:  0.2%  1.8%  0.0%  P16..4:  9.6%  2.1%  1.3%  0.0%  0.0%    skip:85.1%
# [libx264 @ 0x5643855078c0] 8x8 transform intra:62.2% inter:74.7%
# [libx264 @ 0x5643855078c0] coded y,uvDC,uvAC intra: 55.5% 57.6% 16.8% inter: 1.6% 4.5% 0.1%
# [libx264 @ 0x5643855078c0] i16 v,h,dc,p: 36% 27%  7% 30%
# [libx264 @ 0x5643855078c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 14% 16%  5%  7% 10%  8%  7%  7%
# [libx264 @ 0x5643855078c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 16% 11%  7%  9% 12%  8%  8%  7%
# [libx264 @ 0x5643855078c0] i8c dc,h,v,p: 52% 16% 22%  9%
# [libx264 @ 0x5643855078c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5643855078c0] kb/s:2484.00
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/ball.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 598 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 445 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/ball_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 507 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 353 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x5563a6128c00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5563a6128c00] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x5563a6128c00] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/ball_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    2 fps=0.0 q=-1.0 Lsize=       3kB time=00:00:00.04 bitrate= 558.6kbits/s speed=0.602x
# video:2kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 41.230621%
# [libx264 @ 0x5563a6128c00] frame I:1     Avg QP:24.73  size:  1257
# [libx264 @ 0x5563a6128c00] frame P:1     Avg QP:21.52  size:   118
# [libx264 @ 0x5563a6128c00] mb I  I16..4: 60.2% 22.3% 17.6%
# [libx264 @ 0x5563a6128c00] mb P  I16..4:  0.4%  1.2%  0.0%  P16..4: 18.4%  2.0%  0.0%  0.0%  0.0%    skip:78.1%
# [libx264 @ 0x5563a6128c00] 8x8 transform intra:23.1% inter:50.0%
# [libx264 @ 0x5563a6128c00] coded y,uvDC,uvAC intra: 13.2% 11.2% 0.0% inter: 0.3% 0.8% 0.0%
# [libx264 @ 0x5563a6128c00] i16 v,h,dc,p:  2% 15%  4% 79%
# [libx264 @ 0x5563a6128c00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 42% 15%  0%  6%  6% 15%  0%  1%
# [libx264 @ 0x5563a6128c00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 15% 46%  4%  7%  3%  3%  2%  3%
# [libx264 @ 0x5563a6128c00] i8c dc,h,v,p: 74% 15% 10%  0%
# [libx264 @ 0x5563a6128c00] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5563a6128c00] kb/s:132.00
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 699 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 547 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 692 kb/s
# ...
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/69757.jpg_69442.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 3590 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 3460 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/69757.jpg_69442.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 2100 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 1959 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55847fea3280] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55847fea3280] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55847fea3280] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/69757.jpg_69442.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 384x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    2 fps=0.0 q=-1.0 Lsize=      13kB time=00:00:00.04 bitrate=2562.8kbits/s speed=0.639x
# video:12kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.795496%
# [libx264 @ 0x55847fea3280] frame I:1     Avg QP:26.83  size: 11290
# [libx264 @ 0x55847fea3280] frame P:1     Avg QP:30.18  size:   544
# [libx264 @ 0x55847fea3280] mb I  I16..4: 15.1% 38.5% 46.4%
# [libx264 @ 0x55847fea3280] mb P  I16..4:  0.3%  1.8%  0.3%  P16..4:  9.4%  6.5%  5.7%  0.0%  0.0%    skip:76.0%
# [libx264 @ 0x55847fea3280] 8x8 transform intra:39.4% inter:48.3%
# [libx264 @ 0x55847fea3280] coded y,uvDC,uvAC intra: 69.1% 53.9% 20.4% inter: 5.9% 5.3% 0.0%
# [libx264 @ 0x55847fea3280] i16 v,h,dc,p: 53% 14% 19% 15%
# [libx264 @ 0x55847fea3280] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 18% 15% 17%  8%  6%  6%  8%  8% 14%
# [libx264 @ 0x55847fea3280] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 15% 19% 18%  9%  8%  7%  9%  6% 10%
# [libx264 @ 0x55847fea3280] i8c dc,h,v,p: 63% 15% 15%  7%
# [libx264 @ 0x55847fea3280] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55847fea3280] kb/s:1136.06
#  94%|█████████▍| 15/16 [00:23<00:02,  2.15s/it]
# 61234.jpg 64857.jpg
# /data/mint/TPAMI_MajorRevision/Relighting_SOTA/ShadowM/website/axis=1//src=61234.jpg/dst=64857.jpg/Lerp_1000/n_frames=400/
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/61234.jpg_64857.jpg/hou21_rotate_axis=1/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x556b2e865080] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x556b2e865080] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x556b2e865080] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/61234.jpg_64857.jpg/res_hou21_rotate_axis=1.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=      10kB time=00:00:00.00 bitrate=1020246.9kbits/s speed=0.00107x
# video:9kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 8.656779%
# [libx264 @ 0x556b2e865080] frame I:1     Avg QP:23.46  size:  8818
# [libx264 @ 0x556b2e865080] mb I  I16..4:  5.5% 59.4% 35.2%
# [libx264 @ 0x556b2e865080] 8x8 transform intra:59.4%
# [libx264 @ 0x556b2e865080] coded y,uvDC,uvAC intra: 90.0% 62.1% 30.9%
# [libx264 @ 0x556b2e865080] i16 v,h,dc,p: 86%  0%  0% 14%
# [libx264 @ 0x556b2e865080] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25%  9%  5%  7% 11% 14%  7% 13% 10%
# [libx264 @ 0x556b2e865080] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11% 10%  6%  9% 12% 15% 12% 12% 13%
# [libx264 @ 0x556b2e865080] i8c dc,h,v,p: 52% 18% 21%  9%
# [libx264 @ 0x556b2e865080] kb/s:1693.06
# /data/mint/TPAMI_MajorRevision/Relighting_SOTA/GeoConFR/website/axis=1//src=61234.jpg/dst=64857.jpg/Lerp_1000/n_frames=400/
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/61234.jpg_64857.jpg/hou22_rotate_axis=1/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55fa2b816080] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55fa2b816080] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55fa2b816080] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/61234.jpg_64857.jpg/res_hou22_rotate_axis=1.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=       9kB time=00:00:00.00 bitrate=880493.8kbits/s speed=0.00322x
# video:8kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 10.170539%
# [libx264 @ 0x55fa2b816080] frame I:1     Avg QP:22.72  size:  7403
# [libx264 @ 0x55fa2b816080] mb I  I16..4:  3.1% 53.5% 43.4%
# [libx264 @ 0x55fa2b816080] 8x8 transform intra:53.5%
# [libx264 @ 0x55fa2b816080] coded y,uvDC,uvAC intra: 89.6% 64.5% 30.9%
# [libx264 @ 0x55fa2b816080] i16 v,h,dc,p: 50%  0% 12% 38%
# [libx264 @ 0x55fa2b816080] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 33%  7%  5%  5%  8% 12% 10%  9%  9%
# [libx264 @ 0x55fa2b816080] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12%  8%  5% 12% 14% 13% 12% 12% 12%
# [libx264 @ 0x55fa2b816080] i8c dc,h,v,p: 45% 18% 24% 13%
# [libx264 @ 0x55fa2b816080] kb/s:1421.38
#  94%|█████████▍| 15/16 [00:24<00:01,  1.66s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 151
#     149 os.system(cmd)
#     150 try:
# --> 151     subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
#     152 except subprocess.CalledProcessError as e:
#     153     print("An error occurred:", e)
#
# File ~/miniconda3/envs/dpm_sampling_deca_pysh_env/lib/python3.8/subprocess.py:495, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493 with Popen(*popenargs, **kwargs) as process:
#     494     try:
# --> 495         stdout, stderr = process.communicate(input, timeout=timeout)
#     496     except TimeoutExpired as exc:
#     497         process.kill()
#
# File ~/miniconda3/envs/dpm_sampling_deca_pysh_env/lib/python3.8/subprocess.py:1020, in Popen.communicate(self, input, timeout)
#    1018         stderr = self.stderr.read()
#    1019         self.stderr.close()
# -> 1020     self.wait()
#    1021 else:
#    1022     if timeout is not None:
#
# File ~/miniconda3/envs/dpm_sampling_deca_pysh_env/lib/python3.8/subprocess.py:1083, in Popen.wait(self, timeout)
#    1081     endtime = _time() + timeout
#    1082 try:
# -> 1083     return self._wait(timeout=timeout)
#    1084 except KeyboardInterrupt:
#    1085     # https://bugs.python.org/issue25942
#    1086     # The first keyboard interrupt waits briefly for the child to
#    1087     # exit under the common assumption that it also received the ^C
#    1088     # generated SIGINT and will exit rapidly.
#    1089     if timeout is not None:
#
# File ~/miniconda3/envs/dpm_sampling_deca_pysh_env/lib/python3.8/subprocess.py:1822, in Popen._wait(self, timeout)
#    1820 if self.returncode is not None:
#    1821     break  # Another thread waited.
# -> 1822 (pid, sts) = self._try_wait(0)
#    1823 # Check the pid and loop as waitpid has been known to
#    1824 # return 0 even without WNOHANG in odd situations.
#    1825 # http://bugs.python.org/issue14396.
#    1826 if pid == self.pid:
#
# File ~/miniconda3/envs/dpm_sampling_deca_pysh_env/lib/python3.8/subprocess.py:1780, in Popen._try_wait(self, wait_flags)
#    1778 """All callers to this function MUST hold self._waitpid_lock."""
#    1779 try:
# -> 1780     (pid, sts) = os.waitpid(self.pid, wait_flags)
#    1781 except ChildProcessError:
#    1782     # This happens if SIGCLD is set to be ignored or waiting
#    1783     # for child processes has otherwise been disabled for our
#    1784     # process.  This child is dead, we can't get the status.
#    1785     pid = self.pid
#
# KeyboardInterrupt:
