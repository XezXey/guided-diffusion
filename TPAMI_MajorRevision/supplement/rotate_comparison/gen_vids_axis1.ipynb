# %%
import json, os, glob, tqdm
from PIL import Image
import numpy as np
import subprocess

def sort_by_frame(path_list):
    frame_anno = []
    for p in path_list:
        frame_idx = os.path.splitext(p.split('/')[-1].split('_')[-1])[0][5:]   # 0-4 is "frame", so we used [5:] here
        frame_anno.append(int(frame_idx))
    sorted_idx = np.argsort(frame_anno)
    sorted_path_list = []
    for idx in sorted_idx:
      sorted_path_list.append(path_list[idx])
    return sorted_path_list

# %% [markdown]
# # FFHQ: RotateSH_axis1.json

# %%
ax = 1

# sample_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/experiment_scripts/TPAMI/sample_json/TPAMI_MajorRevision/rotateSH_axis1.json", "r"))
sample_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/experiment_scripts/TPAMI/sample_json/TPAMI_MajorRevision/website.json", "r"))

method = ["hou21_rotate_axis=1", "hou22_rotate_axis=1", "diffusionrig_rotate_axis=1_0.7sh", "iclight_rotate_512x512_map_centered_axis1", "relipa_rotate_axis=1_0.6sh", "ours_difareli_rotate_rot1_0.7sh_250t", "ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh"]
# meta_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/visualize_scripts/TPAMI/MajorRevision/figure/ffhq/rotateSH_axis1.json", "r"))
meta_dat = json.load(open("./for_rotate1_website.json", "r"))


os.makedirs("./vids/", exist_ok=True)
os.makedirs(f'./vids/all_outputs/res/', exist_ok=True)
os.makedirs(f'./vids/all_outputs/misc/', exist_ok=True)

no_f1 = True
focus_src = [f'{f}.jpg' for f in [62848, 60208, 69757, 61234]]
use_offset = True
start_offset = 30
end_offset = 210

target_n_frames = 60

for sample_id, sample in tqdm.tqdm(sample_dat['pair'].items()):
    src = sample['src']
    dst = sample['dst']
    if src not in focus_src:
        continue
    print(src, dst)
    for m in method:
        img_dir = meta_dat[m]['img_dir']
        n_frames = meta_dat[m]['n_frame']
        itp_method = meta_dat[m]['itp_method']
        diff_step = meta_dat[m]['diff_step']
        n_frame_tmp = meta_dat[m]['n_frame']
        
        os.makedirs(f'./vids/axis={ax}/{src}_{dst}/{m}/', exist_ok=True)
        if "hou21" in m or "hou22" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            print(img_path)
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
            idx = np.linspace(0, len(relit)-1, target_n_frames, dtype=int)
            relit = [relit[i] for i in idx]
            
        elif "iclight" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
            idx = np.linspace(0, len(relit)-1, target_n_frames, dtype=int)
            relit = [relit[i] for i in idx]
        elif m == "diffusionrig_rotate_axis=1_0.7sh":
            img_path = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/n_frames={n_frame_tmp}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:]
            idx = np.linspace(0, len(relit)-1, target_n_frames, dtype=int)
            relit = [relit[i] for i in idx]
            
        elif m == "relipa_rotate_axis=1_0.6sh":
            img_path = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/gs=4.5_ds=25/n_frames={n_frame_tmp}/256/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:]
            idx = np.linspace(0, len(relit)-1, target_n_frames, dtype=int)
            relit = [relit[i] for i in idx]
        elif "difareli++" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:][start_offset:end_offset]
                shadow = sort_by_frame(glob.glob(f'{img_path}/dst_shadm_shad_f*.png'))[1:][start_offset:end_offset]
                render = sort_by_frame(glob.glob(f'{img_path}/dst_ren_f*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
                shadow = sort_by_frame(glob.glob(f'{img_path}/dst_shadm_shad_f*.png'))[1:]
                render = sort_by_frame(glob.glob(f'{img_path}/dst_ren_f*.png'))[1:]
            idx = np.linspace(0, len(relit)-1, target_n_frames, dtype=int)
            relit = [relit[i] for i in idx]
            shadow = [shadow[i] for i in idx]
            render = [render[i] for i in idx]
            for _, (s, r) in enumerate(zip(shadow, render)):
                i = int(s.split('/')[-1].split('frame')[-1].split('.')[0])
                assert i == int(r.split('/')[-1].split('frame')[-1].split('.')[0])
                os.system(f'cp {s} ./vids/axis={ax}/{src}_{dst}/{m}/dst_shadm_shad_frame_{i:04d}.png')
                os.system(f'cp {r} ./vids/axis={ax}/{src}_{dst}/{m}/dst_ren_frame_{i:04d}.png')

            assert len(relit) == len(shadow) == len(render)
            for j in range(len(relit)):
                frame_id = int(relit[j].split('/')[-1].split('frame')[-1].split('.')[0])
                r_tmp = np.array(Image.open(relit[j]))
                h, w, _ = r_tmp.shape
                s_tmp = np.array(Image.open(shadow[j]).resize((h//2, w//2)))
                ren_tmp = np.array(Image.open(render[j]).resize((h//2, w//2)))
                
                out_comb = np.concatenate((r_tmp, np.concatenate((ren_tmp, s_tmp), axis=0)), axis=1)
                Image.fromarray(out_comb).save(f'./vids/axis={ax}/{src}_{dst}/{m}/res+cond_frame_{frame_id:04d}.png')
             
            if use_offset:   
                start_num = start_offset
            else:
                start_num = 0
            cmds = [f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/{m}/dst_shadm_shad_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/shadow.mp4',
                    f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/{m}/dst_ren_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/render.mp4',
                    # Vertical stack them (render on top of shadow)
                    f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/render.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/shadow.mp4 -filter_complex vstack ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4',
                    f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4'
            ]
            for c in cmds:
                try:
                    subprocess.run(c, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
                except subprocess.CalledProcessError as e:
                    print("An error occurred:", e)
        
        
            
        elif "difareli" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            if use_offset:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:][start_offset:end_offset]
            else:
                relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
            idx = np.linspace(0, len(relit)-1, target_n_frames, dtype=int)
            relit = [relit[i] for i in idx]
        
        if len(relit) == 0:
            # Create 0 images for mockup and match the number of frames
            for i in range(1, int(n_frames)):
                img = Image.new('RGB', (256, 256), color='black')
                img.save(f'./vids/axis={ax}/{src}_{dst}/{m}/res_frame_{i:04d}.png')
            continue
        
        os.makedirs(f'./vids/axis={ax}/{src}_{dst}/{m}/', exist_ok=True)
        # Copy all images to a new folder
        for img in relit:
            i = int(img.split('/')[-1].split('frame')[-1].split('.')[0])
            os.system(f'cp {img} ./vids/axis={ax}/{src}_{dst}/{m}/res_frame_{i:04d}.png')
        
        #NOTE: Generate video low compression with 24 fps
        if use_offset:
            start_num = start_offset
        else:
            start_num = 0
        cmd = f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/{m}/res_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/res_{m}.mp4'
        os.system(cmd)
        try:
            subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
        except subprocess.CalledProcessError as e:
            print("An error occurred:", e)


    # Copy the ball image
    ball = sorted(glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_website/axis={ax}/valid/{sample_id}_src={src}_dst={dst}/n_step={n_frames}/ball/m_*.png"))
    print(len(ball), n_frames)
    assert len(ball) == int(n_frames)
    if no_f1:
        if use_offset:
            ball = ball[1:][start_offset:end_offset]
        else:
            ball = ball[1:]
        idx = np.linspace(0, len(ball)-1, target_n_frames, dtype=int)
        ball = [ball[i] for i in idx]
    os.makedirs(f'./vids/axis={ax}/{src}_{dst}/ball/', exist_ok=True)
    for img in ball:
        os.system(f'cp {img} ./vids/axis={ax}/{src}_{dst}/ball/{img.split("/")[-1]}')

    if use_offset:
        start_num = start_offset
    else:
        start_num = 0
    cmd = f'ffmpeg -y -r 24 -start_number {start_num} -i ./vids/axis={ax}/{src}_{dst}/ball/m_%03d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/ball.mp4'
    try:
        subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
    except subprocess.CalledProcessError as e:
        print("An error occurred:", e)

    # Concatenate all videos vertically following the method order
    video_list = []
    for m in method:
        if os.path.exists(f'./vids/axis={ax}/{src}_{dst}/res_{m}.mp4'):
            if "difareli++" in m:
                video_list.append(f'./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4')
            else:
                video_list.append(f'./vids/axis={ax}/{src}_{dst}/res_{m}.mp4')
    # video_list.append(f'./vids/axis={ax}/{src}_{dst}/ball.mp4')
    
    num_videos = len(video_list)
    # Generate FFmpeg inputs and filter_complex dynamically
    input_files = " ".join(f"-i {path}" for path in video_list)
    filter_complex = "".join(f"[{i}:v:0]" for i in range(num_videos)) + f"hstack=inputs={num_videos}"

    # Output file
    output_file = f"./vids/axis={ax}/{src}_{dst}/res_all.mp4"

    # Construct the FFmpeg command
    command = f"ffmpeg {input_files} -filter_complex \"{filter_complex}\" -c:v libx264 -crf 17 -preset slow {output_file}"

    # Execute the command
    try:
        subprocess.run(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
    except subprocess.CalledProcessError as e:
        print("An error occurred:", e)

    # Create the reverse video of res_all.mp4, ball.mp4 and cond.mp4
    os.system(f'ffmpeg -i {output_file} -vf reverse ./vids/axis={ax}/{src}_{dst}/res_all_reverse.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/{m}/cond_reverse.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/ball.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/ball_reverse.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_reverse.mp4')

    # Time concatenation
    filter_cat = f'-filter_complex "[0:v][1:v]concat=n=2:v=1:a=0"'
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/res_all.mp4 -i ./vids/axis={ax}/{src}_{dst}/res_all_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/res_all_concat.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/ball.mp4 -i ./vids/axis={ax}/{src}_{dst}/ball_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/ball_concat.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/cond_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/{m}/cond_concat.mp4')
    os.system(f'ffmpeg -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_concat.mp4')

    # Copy the res_all.mp4 and ball.mp4 to ./vids/all_outputs/ and rename them with {src}_{dst}_{ax}.mp4
    os.system(f'cp /data/mint/DPM_Dataset/ffhq_256_with_anno/ffhq_256/valid/{src} ./vids/all_outputs/res/{src}')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/res_all_concat.mp4 ./vids/all_outputs/res/{src}_{dst}_{ax}.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/ball_concat.mp4 ./vids/all_outputs/res/{src}_{dst}_{ax}_ball.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/{m}/cond_concat.mp4 ./vids/all_outputs/misc/{src}_{dst}_{ax}_cond.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_concat.mp4 ./vids/all_outputs/misc/{src}_{dst}_{ax}_res+cond.mp4')
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/62848.jpg_66729.jpg/hou21_rotate_axis=1/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# 62848.jpg 66729.jpg
# /data/mint/TPAMI_MajorRevision/Relighting_SOTA/ShadowM/website/axis=1//src=62848.jpg/dst=66729.jpg/Lerp_1000/n_frames=400/
# [libx264 @ 0x56091bff1080] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56091bff1080] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x56091bff1080] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_hou21_rotate_axis=1.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=       9kB time=00:00:00.00 bitrate=946666.7kbits/s speed=0.000986x
# video:9kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 9.392833%
# [libx264 @ 0x56091bff1080] frame I:1     Avg QP:21.25  size:  8073
# [libx264 @ 0x56091bff1080] mb I  I16..4:  3.9% 74.2% 21.9%
# [libx264 @ 0x56091bff1080] 8x8 transform intra:74.2%
# [libx264 @ 0x56091bff1080] coded y,uvDC,uvAC intra: 87.8% 68.8% 45.7%
# [libx264 @ 0x56091bff1080] i16 v,h,dc,p: 30%  0% 50% 20%
# [libx264 @ 0x56091bff1080] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 12% 10% 11%  6% 12% 17% 10% 12% 10%
# [libx264 @ 0x56091bff1080] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7%  9%  8% 10% 12% 14% 11% 15% 13%
# [libx264 @ 0x56091bff1080] i8c dc,h,v,p: 48% 15% 20% 17%
# [libx264 @ 0x56091bff1080] kb/s:1550.02
# /data/mint/TPAMI_MajorRevision/Relighting_SOTA/GeoConFR/website/axis=1//src=62848.jpg/dst=66729.jpg/Lerp_1000/n_frames=400/
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/62848.jpg_66729.jpg/hou22_rotate_axis=1/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55e8325b4080] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55e8325b4080] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55e8325b4080] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_hou22_rotate_axis=1.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=       8kB time=00:00:00.00 bitrate=809185.2kbits/s speed=0.000988x
# video:7kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 11.166893%
# [libx264 @ 0x55e8325b4080] frame I:1     Avg QP:20.27  size:  6681
# [libx264 @ 0x55e8325b4080] mb I  I16..4:  8.6% 70.3% 21.1%
# [libx264 @ 0x55e8325b4080] 8x8 transform intra:70.3%
# [libx264 @ 0x55e8325b4080] coded y,uvDC,uvAC intra: 83.1% 68.4% 39.5%
# [libx264 @ 0x55e8325b4080] i16 v,h,dc,p: 50% 18% 32%  0%
# [libx264 @ 0x55e8325b4080] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10% 11% 12%  9% 11% 14% 13% 10%  9%
# [libx264 @ 0x55e8325b4080] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8%  7%  6% 10% 12% 19% 12% 12% 13%
# [libx264 @ 0x55e8325b4080] i8c dc,h,v,p: 48% 16% 19% 18%
# [libx264 @ 0x55e8325b4080] kb/s:1282.75
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/62848.jpg_66729.jpg/diffusionrig_rotate_axis=1_0.7sh/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55d37dc86080] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55d37dc86080] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55d37dc86080] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_diffusionrig_rotate_axis=1_0.7sh.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=       5kB time=00:00:00.00 bitrate=539358.0kbits/s speed=0.00103x
# video:5kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 17.744717%
# [libx264 @ 0x55d37dc86080] frame I:1     Avg QP:20.07  size:  3949
# [libx264 @ 0x55d37dc86080] mb I  I16..4: 13.3% 69.1% 17.6%
# [libx264 @ 0x55d37dc86080] 8x8 transform intra:69.1%
# [libx264 @ 0x55d37dc86080] coded y,uvDC,uvAC intra: 63.2% 74.6% 37.1%
# [libx264 @ 0x55d37dc86080] i16 v,h,dc,p:  9% 47% 15% 29%
# [libx264 @ 0x55d37dc86080] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 13% 17% 11%  8%  8% 14%  8%  8% 14%
# [libx264 @ 0x55d37dc86080] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  6%  8% 19%  8% 16% 15% 12%  7%  9%
# [libx264 @ 0x55d37dc86080] i8c dc,h,v,p: 31% 30% 18% 21%
# [libx264 @ 0x55d37dc86080] kb/s:758.21
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/62848.jpg_66729.jpg/iclight_rotate_512x512_map_centered_axis1/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x558dedbf2380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x558dedbf2380] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x558dedbf2380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_iclight_rotate_512x512_map_centered_axis1.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=       9kB time=00:00:00.00 bitrate=896296.3kbits/s speed=0.000983x
# video:8kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 9.973340%
# [libx264 @ 0x558dedbf2380] frame I:1     Avg QP:22.89  size:  7563
# [libx264 @ 0x558dedbf2380] mb I  I16..4: 16.8% 64.5% 18.8%
# [libx264 @ 0x558dedbf2380] 8x8 transform intra:64.5%
# [libx264 @ 0x558dedbf2380] coded y,uvDC,uvAC intra: 69.3% 71.9% 51.6%
# [libx264 @ 0x558dedbf2380] i16 v,h,dc,p:  0% 14%  0% 86%
# [libx264 @ 0x558dedbf2380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu:  9% 16%  9%  5% 16% 12% 16%  7% 10%
# [libx264 @ 0x558dedbf2380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  8%  9%  7% 10% 17% 15% 11% 10% 12%
# [libx264 @ 0x558dedbf2380] i8c dc,h,v,p: 34% 25% 20% 21%
# [libx264 @ 0x558dedbf2380] kb/s:1452.10
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/62848.jpg_66729.jpg/relipa_rotate_axis=1_0.6sh/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55c0c730f080] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55c0c730f080] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55c0c730f080] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_relipa_rotate_axis=1_0.6sh.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=       7kB time=00:00:00.00 bitrate=711209.9kbits/s speed=0.00101x
# video:6kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 12.903731%
# [libx264 @ 0x55c0c730f080] frame I:1     Avg QP:20.68  size:  5689
# [libx264 @ 0x55c0c730f080] mb I  I16..4: 15.6% 65.6% 18.8%
# [libx264 @ 0x55c0c730f080] 8x8 transform intra:65.6%
# [libx264 @ 0x55c0c730f080] coded y,uvDC,uvAC intra: 76.4% 69.9% 43.8%
# [libx264 @ 0x55c0c730f080] i16 v,h,dc,p: 32% 30%  5% 32%
# [libx264 @ 0x55c0c730f080] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11%  9%  7%  8% 15% 16% 12% 13% 10%
# [libx264 @ 0x55c0c730f080] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7%  9% 14% 14% 13% 13%  9% 10% 10%
# [libx264 @ 0x55c0c730f080] i8c dc,h,v,p: 34% 21% 17% 28%
# [libx264 @ 0x55c0c730f080] kb/s:1092.29
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/62848.jpg_66729.jpg/ours_difareli_rotate_rot1_0.7sh_250t/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x555e3aeb6380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x555e3aeb6380] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x555e3aeb6380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_ours_difareli_rotate_rot1_0.7sh_250t.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=       9kB time=00:00:00.00 bitrate=943308.6kbits/s speed=0.00096x
# video:9kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 9.429422%
# [libx264 @ 0x555e3aeb6380] frame I:1     Avg QP:20.90  size:  8039
# [libx264 @ 0x555e3aeb6380] mb I  I16..4: 10.5% 71.5% 18.0%
# [libx264 @ 0x555e3aeb6380] 8x8 transform intra:71.5%
# [libx264 @ 0x555e3aeb6380] coded y,uvDC,uvAC intra: 86.4% 68.4% 46.5%
# [libx264 @ 0x555e3aeb6380] i16 v,h,dc,p: 59% 22% 19%  0%
# [libx264 @ 0x555e3aeb6380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 10% 11%  8%  9% 12% 14% 12% 11% 14%
# [libx264 @ 0x555e3aeb6380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu:  7%  5%  4% 12% 14% 18% 12% 15% 13%
# [libx264 @ 0x555e3aeb6380] i8c dc,h,v,p: 42% 17% 20% 21%
# [libx264 @ 0x555e3aeb6380] kb/s:1543.49
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, image2, from './vids/axis=1/62848.jpg_66729.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res_frame_%04d.png':
#   Duration: 00:00:00.04, start: 0.000000, bitrate: N/A
#   Stream #0:0: Video: png, rgb24(pc), 256x256, 25 fps, 25 tbr, 25 tbn, 25 tbc
# Stream mapping:
#   Stream #0:0 -> #0:0 (png (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5608302b2240] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5608302b2240] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x5608302b2240] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=5 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=8 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=2 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=3 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=50 rc=crf mbtree=1 crf=17.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh.mp4':
#   Metadata:
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(tv, progressive), 256x256, q=2-31, 24 fps, 12288 tbn
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=22.0 Lsize=       8kB time=00:00:00.00 bitrate=835061.7kbits/s speed=0.0012x
# video:7kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 10.783543%
# [libx264 @ 0x5608302b2240] frame I:1     Avg QP:20.61  size:  6943
# [libx264 @ 0x5608302b2240] mb I  I16..4:  1.2% 82.0% 16.8%
# [libx264 @ 0x5608302b2240] 8x8 transform intra:82.0%
# [libx264 @ 0x5608302b2240] coded y,uvDC,uvAC intra: 87.7% 71.1% 38.7%
# [libx264 @ 0x5608302b2240] i16 v,h,dc,p: 33% 33%  0% 33%
# [libx264 @ 0x5608302b2240] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11%  9%  7%  8% 15% 16% 13% 11% 12%
# [libx264 @ 0x5608302b2240] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 11%  6%  4% 17% 11% 16% 11% 13% 12%
# [libx264 @ 0x5608302b2240] i8c dc,h,v,p: 36% 17% 15% 32%
# [libx264 @ 0x5608302b2240] kb/s:1333.06
# 400 400
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/res_all.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 9241 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 9157 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55de5ad6e7c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55de5ad6e7c0] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x55de5ad6e7c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/res_all_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=28.0 Lsize=      23kB time=00:00:00.00 bitrate=2299358.0kbits/s speed=0.000987x
# video:22kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.664618%
# [libx264 @ 0x55de5ad6e7c0] frame I:1     Avg QP:26.99  size: 21769
# [libx264 @ 0x55de5ad6e7c0] mb I  I16..4: 14.1% 67.2% 18.8%
# [libx264 @ 0x55de5ad6e7c0] 8x8 transform intra:67.2%
# [libx264 @ 0x55de5ad6e7c0] coded y,uvDC,uvAC intra: 56.1% 56.0% 15.1%
# [libx264 @ 0x55de5ad6e7c0] i16 v,h,dc,p: 34% 25% 15% 26%
# [libx264 @ 0x55de5ad6e7c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 15% 14%  6%  8% 11%  8%  6%  7%
# [libx264 @ 0x55de5ad6e7c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 15% 11%  7% 10% 10%  7%  8%  6%
# [libx264 @ 0x55de5ad6e7c0] i8c dc,h,v,p: 52% 16% 25%  8%
# [libx264 @ 0x55de5ad6e7c0] kb/s:4179.65
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 732 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 580 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55570e58c540] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55570e58c540] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x55570e58c540] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x512, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=28.0 Lsize=       4kB time=00:00:00.00 bitrate=374814.8kbits/s speed=0.00132x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 27.691790%
# [libx264 @ 0x55570e58c540] frame I:1     Avg QP:25.60  size:  2282
# [libx264 @ 0x55570e58c540] mb I  I16..4: 13.7% 67.6% 18.8%
# [libx264 @ 0x55570e58c540] 8x8 transform intra:67.6%
# [libx264 @ 0x55570e58c540] coded y,uvDC,uvAC intra: 16.5% 2.5% 0.0%
# [libx264 @ 0x55570e58c540] i16 v,h,dc,p: 57%  6% 30%  7%
# [libx264 @ 0x55570e58c540] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 47% 22% 23%  1%  2%  3%  1%  1%  1%
# [libx264 @ 0x55570e58c540] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 25% 15%  5%  4%  4%  5%  5%  3%
# [libx264 @ 0x55570e58c540] i8c dc,h,v,p: 91%  3%  5%  0%
# [libx264 @ 0x55570e58c540] kb/s:438.14
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/ball.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 611 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 458 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5560ddf5bcc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5560ddf5bcc0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x5560ddf5bcc0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/ball_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=28.0 Lsize=       3kB time=00:00:00.00 bitrate=270321.0kbits/s speed=0.0021x
# video:2kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 42.998955%
# [libx264 @ 0x5560ddf5bcc0] frame I:1     Avg QP:26.08  size:  1225
# [libx264 @ 0x5560ddf5bcc0] mb I  I16..4: 53.5% 30.1% 16.4%
# [libx264 @ 0x5560ddf5bcc0] 8x8 transform intra:30.1%
# [libx264 @ 0x5560ddf5bcc0] coded y,uvDC,uvAC intra: 14.6% 13.7% 0.0%
# [libx264 @ 0x5560ddf5bcc0] i16 v,h,dc,p:  7% 15%  7% 71%
# [libx264 @ 0x5560ddf5bcc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 14% 29% 24%  0% 16%  3% 12%  0%  1%
# [libx264 @ 0x5560ddf5bcc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 20%  7% 45%  5%  8%  5%  3%  3%  3%
# [libx264 @ 0x5560ddf5bcc0] i8c dc,h,v,p: 75% 14% 11%  0%
# [libx264 @ 0x5560ddf5bcc0] kb/s:235.20
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/62848.jpg_66729.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 1913 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 1771 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x557331782380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x557331782380] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x557331782380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/62848.jpg_66729.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 384x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=28.0 Lsize=       5kB time=00:00:00.00 bitrate=511506.2kbits/s speed=0.00111x
# video:4kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 18.893480%
# [libx264 @ 0x557331782380] frame I:1     Avg QP:27.35  size:  3667
# [libx264 @ 0x557331782380] mb I  I16..4: 10.9% 65.6% 23.4%
# [libx264 @ 0x557331782380] 8x8 transform intra:65.6%
# [libx264 @ 0x557331782380] coded y,uvDC,uvAC intra: 47.3% 37.0% 6.0%
# [libx264 @ 0x557331782380] i16 v,h,dc,p: 36% 10% 43% 12%
# [libx264 @ 0x557331782380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 36% 16% 15%  6%  5%  9%  6%  4%  5%
# [libx264 @ 0x557331782380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 17% 18%  7%  8% 11%  6%  6%  6%
# [libx264 @ 0x557331782380] i8c dc,h,v,p: 69% 12% 14%  5%
# [libx264 @ 0x557331782380] kb/s:704.06
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/61234.jpg_64857.jpg/ball.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 685 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 533 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/61234.jpg_64857.jpg/ball_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 576 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 422 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x564b44a7d9c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x564b44a7d9c0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x564b44a7d9c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/61234.jpg_64857.jpg/ball_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    2 fps=0.0 q=-1.0 Lsize=       3kB time=00:00:00.04 bitrate= 631.0kbits/s speed=0.604x
# video:2kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 34.848484%
# [libx264 @ 0x564b44a7d9c0] frame I:1     Avg QP:25.03  size:  1647
# [libx264 @ 0x564b44a7d9c0] frame P:1     Avg QP:21.92  size:   106
# [libx264 @ 0x564b44a7d9c0] mb I  I16..4: 48.4% 28.9% 22.7%
# [libx264 @ 0x564b44a7d9c0] mb P  I16..4:  0.0%  0.8%  0.0%  P16..4: 16.0%  0.8%  0.4%  0.0%  0.0%    skip:82.0%
# [libx264 @ 0x564b44a7d9c0] 8x8 transform intra:29.5% inter:100.0%
# [libx264 @ 0x564b44a7d9c0] coded y,uvDC,uvAC intra: 19.5% 16.7% 0.0% inter: 0.4% 1.2% 0.0%
# [libx264 @ 0x564b44a7d9c0] i16 v,h,dc,p: 19%  4%  6% 72%
# [libx264 @ 0x564b44a7d9c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 55% 11% 18%  3%  1%  5%  0%  6%  0%
# [libx264 @ 0x564b44a7d9c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 14% 31%  7%  3%  4%  3%  5%  2%
# [libx264 @ 0x564b44a7d9c0] i8c dc,h,v,p: 66% 10% 22%  2%
# [libx264 @ 0x564b44a7d9c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x564b44a7d9c0] kb/s:168.29
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 718 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 566 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 709 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 557 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x562ead485380] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x562ead485380] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x562ead485380] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/cond_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x512, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    2 fps=0.0 q=-1.0 Lsize=       4kB time=00:00:00.04 bitrate= 752.1kbits/s speed=0.571x
# video:3kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 27.683800%
# [libx264 @ 0x562ead485380] frame I:1     Avg QP:23.96  size:  2340
# [libx264 @ 0x562ead485380] frame P:1     Avg QP:13.00  size:    44
# [libx264 @ 0x562ead485380] mb I  I16..4: 12.3% 70.1% 17.6%
# [libx264 @ 0x562ead485380] mb P  I16..4:  1.0%  0.0%  0.0%  P16..4:  1.0%  0.2%  0.0%  0.0%  0.0%    skip:97.9%
# [libx264 @ 0x562ead485380] 8x8 transform intra:69.4%
# [libx264 @ 0x562ead485380] coded y,uvDC,uvAC intra: 18.3% 3.9% 0.0% inter: 0.0% 0.0% 0.0%
# [libx264 @ 0x562ead485380] i16 v,h,dc,p: 62%  1% 31%  6%
# [libx264 @ 0x562ead485380] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 43% 24% 26%  2%  1%  1%  0%  2%  1%
# [libx264 @ 0x562ead485380] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 38% 23% 15%  7%  3%  4%  3%  4%  3%
# [libx264 @ 0x562ead485380] i8c dc,h,v,p: 90%  2%  7%  0%
# [libx264 @ 0x562ead485380] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x562ead485380] kb/s:228.86
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 2043 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 1901 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=1/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:00.04, start: 0.000000, bitrate: 1212 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 1064 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x563e55c4ac80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x563e55c4ac80] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x563e55c4ac80] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=1/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot1_0.6C_rot1_0.7sh/res+cond_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 384x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    2 fps=0.0 q=-1.0 Lsize=       7kB time=00:00:00.04 bitrate=1426.5kbits/s speed=0.758x
# video:6kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 12.907629%
# [libx264 @ 0x563e55c4ac80] frame I:1     Avg QP:25.95  size:  5681
# [libx264 @ 0x563e55c4ac80] frame P:1     Avg QP:28.60  size:   223
# [libx264 @ 0x563e55c4ac80] mb I  I16..4: 18.2% 46.9% 34.9%
# [libx264 @ 0x563e55c4ac80] mb P  I16..4:  0.0%  0.5%  0.3%  P16..4:  8.9%  1.3%  1.3%  0.0%  0.0%    skip:87.8%
# [libx264 @ 0x563e55c4ac80] 8x8 transform intra:47.0% inter:66.7%
# [libx264 @ 0x563e55c4ac80] coded y,uvDC,uvAC intra: 55.9% 38.2% 10.3% inter: 1.7% 4.5% 0.0%
# [libx264 @ 0x563e55c4ac80] i16 v,h,dc,p: 80%  4%  4% 11%
# [libx264 @ 0x563e55c4ac80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 13% 16%  3%  7% 11%  4%  6%  6%
# [libx264 @ 0x563e55c4ac80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 15% 17%  8%  7%  7%  5%  6%  6%
# [libx264 @ 0x563e55c4ac80] i8c dc,h,v,p: 63%  9% 23%  4%
# [libx264 @ 0x563e55c4ac80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x563e55c4ac80] kb/s:566.78
# 100%|██████████| 16/16 [00:29<00:00,  1.82s/it]
