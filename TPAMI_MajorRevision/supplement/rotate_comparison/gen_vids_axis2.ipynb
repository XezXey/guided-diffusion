# %%
import json, os, glob, tqdm
from PIL import Image
import numpy as np
import subprocess

def sort_by_frame(path_list):
    frame_anno = []
    for p in path_list:
        frame_idx = os.path.splitext(p.split('/')[-1].split('_')[-1])[0][5:]   # 0-4 is "frame", so we used [5:] here
        frame_anno.append(int(frame_idx))
    sorted_idx = np.argsort(frame_anno)
    sorted_path_list = []
    for idx in sorted_idx:
      sorted_path_list.append(path_list[idx])
    return sorted_path_list

# %% [markdown]
# # FFHQ: RotateSH_axis2.json

# %%
ax = 2

method = ["hou21_rotate_axis=2", "hou22_rotate_axis=2", "diffusionrig_rotate_axis=2", "iclight_rotate_512x512_map_centered_axis2", "relipa_rotate_axis=2", "ours_256_difareli_rotate_rot2", "ours_difareli++_oneshot_rotate_rot2_tomax"]
sample_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/experiment_scripts/TPAMI/sample_json/TPAMI_MajorRevision/rotateSH_axis2.json", "r"))
meta_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/visualize_scripts/TPAMI/MajorRevision/figure/ffhq/rotateSH_axis2.json", "r"))

os.makedirs("./vids/", exist_ok=True)
os.makedirs(f'./vids/all_outputs/res/', exist_ok=True)
os.makedirs(f'./vids/all_outputs/misc/', exist_ok=True)

no_f1 = True

for sample_id, sample in tqdm.tqdm(sample_dat['pair'].items()):
    src = sample['src']
    dst = sample['dst']
    for m in method:
        img_dir = meta_dat[m]['img_dir']
        n_frames = meta_dat[m]['n_frame']
        itp_method = meta_dat[m]['itp_method']
        diff_step = meta_dat[m]['diff_step']
        n_frame_tmp = meta_dat[m]['n_frame']
        os.makedirs(f'./vids/axis={ax}/{src}_{dst}/{m}/', exist_ok=True)
        if "hou21" in m or "hou22" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
        elif "iclight" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
        elif m == "diffusionrig_rotate_axis=2":
            img_path = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/n_frames={n_frame_tmp}/'
            relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:]
        elif m == "relipa_rotate_axis=2":
            img_path = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/gs=4.5_ds=25/n_frames={n_frame_tmp}/256/'
            relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:]
        elif "difareli++" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
            shadow = sort_by_frame(glob.glob(f'{img_path}/dst_shadm_shad_f*.png'))[1:]
            render = sort_by_frame(glob.glob(f'{img_path}/dst_ren_f*.png'))[1:]
            for _, (s, r) in enumerate(zip(shadow, render)):
                i = int(s.split('/')[-1].split('frame')[-1].split('.')[0])
                assert i == int(r.split('/')[-1].split('frame')[-1].split('.')[0])
                os.system(f'cp {s} ./vids/axis={ax}/{src}_{dst}/{m}/dst_shadm_shad_frame_{i:04d}.png')
                os.system(f'cp {r} ./vids/axis={ax}/{src}_{dst}/{m}/dst_ren_frame_{i:04d}.png')

            assert len(relit) == len(shadow) == len(render)
            for j in range(len(relit)):
                r_tmp = np.array(Image.open(relit[j]))
                h, w, _ = r_tmp.shape
                s_tmp = np.array(Image.open(shadow[j]).resize((h//2, w//2)))
                ren_tmp = np.array(Image.open(render[j]).resize((h//2, w//2)))
                
                out_comb = np.concatenate((r_tmp, np.concatenate((ren_tmp, s_tmp), axis=0)), axis=1)
                Image.fromarray(out_comb).save(f'./vids/axis={ax}/{src}_{dst}/{m}/res+cond_frame_{j:04d}.png')
                
            cmds = [f'ffmpeg -y -r 24 -i ./vids/axis={ax}/{src}_{dst}/{m}/dst_shadm_shad_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/shadow.mp4',
                    f'ffmpeg -y -r 24 -i ./vids/axis={ax}/{src}_{dst}/{m}/dst_ren_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/render.mp4',
                    # Vertical stack them (render on top of shadow)
                    f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/render.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/shadow.mp4 -filter_complex vstack ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4',
                    f'ffmpeg -y -r 24 -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4'
            ]
            for c in cmds:
                try:
                    subprocess.run(c, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
                except subprocess.CalledProcessError as e:
                    print("An error occurred:", e)
        
        
            
        elif "difareli" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
        
        if len(relit) == 0:
            # Create 0 images for mockup and match the number of frames
            for i in range(1, int(n_frames)):
                img = Image.new('RGB', (256, 256), color='black')
                img.save(f'./vids/axis={ax}/{src}_{dst}/{m}/res_frame_{i:04d}.png')
            continue
        
        os.makedirs(f'./vids/axis={ax}/{src}_{dst}/{m}/', exist_ok=True)
        # Copy all images to a new folder
        for img in relit:
            i = int(img.split('/')[-1].split('frame')[-1].split('.')[0])
            os.system(f'cp {img} ./vids/axis={ax}/{src}_{dst}/{m}/res_frame_{i:04d}.png')
        
        #NOTE: Generate video high compression with 24 fps
        cmd = f'ffmpeg -y -r 24 -i ./vids/axis={ax}/{src}_{dst}/{m}/res_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/res_{m}.mp4'
        try:
            subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
        except subprocess.CalledProcessError as e:
            print("An error occurred:", e)


    # Copy the ball image
    # ttmp = glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_user_study/axis={ax}/valid/*_src={src}_dst={dst}")
    # ttmp = glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_user_study/axis={ax}/valid/*_src={src}_dst={dst}")
    # if len(ttmp) == 0:
    #     print(f"Cannot find the ball image for {src} to {dst} on axis {ax}")
    #     continue
    # ttmp = ttmp[0].split('/')[-1].replace(f'_src={src}_dst={dst}', '')
    # sample_id_revoke = ttmp
    # if sample_id != sample_id_revoke:
    #     ball = sorted(glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_user_study/axis={ax}/valid/{sample_id_revoke}_src={src}_dst={dst}/n_step={n_frames}/ball/m_*.png"))
    # else:
    # ball = sorted(glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_user_study/axis={ax}/valid/{sample_id}_src={src}_dst={dst}/n_step={n_frames}/ball/m_*.png"))
    ball = sorted(glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_selected_rotateSH/axis={ax}/valid/{sample_id}_src={src}_dst={dst}/n_step={n_frames}/ball/m_*.png"))
    print(len(ball), int(n_frames))
    assert len(ball) == int(n_frames)
    if no_f1:
        ball = ball[1:]
    os.makedirs(f'./vids/axis={ax}/{src}_{dst}/ball/', exist_ok=True)
    for img in ball:
        os.system(f'cp {img} ./vids/axis={ax}/{src}_{dst}/ball/{img.split("/")[-1]}')

    cmd = f'ffmpeg -y -r 24 -i ./vids/axis={ax}/{src}_{dst}/ball/m_%03d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/ball.mp4'
    try:
        subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
    except subprocess.CalledProcessError as e:
        print("An error occurred:", e)

    # Concatenate all videos vertically following the method order
    video_list = []
    for m in method:
        if os.path.exists(f'./vids/axis={ax}/{src}_{dst}/res_{m}.mp4'):
            if "difareli++" in m:
                video_list.append(f'./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4')
            else:
                video_list.append(f'./vids/axis={ax}/{src}_{dst}/res_{m}.mp4')
    # video_list.append(f'./vids/axis={ax}/{src}_{dst}/ball.mp4')
    
    num_videos = len(video_list)
    # Generate FFmpeg inputs and filter_complex dynamically
    input_files = " ".join(f"-i {path}" for path in video_list)
    filter_complex = "".join(f"[{i}:v:0]" for i in range(num_videos)) + f"hstack=inputs={num_videos}"

    # Output file
    output_file = f"./vids/axis={ax}/{src}_{dst}/res_all.mp4"

    # Construct the FFmpeg command
    command = f"ffmpeg -y {input_files} -filter_complex \"{filter_complex}\" -c:v libx264 -crf 17 -preset slow {output_file}"

    # Execute the command
    try:
        subprocess.run(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
    except subprocess.CalledProcessError as e:
        print("An error occurred:", e)

    # Create the reverse video of res_all.mp4, ball.mp4 and cond.mp4
    os.system(f'ffmpeg -y -i {output_file} -vf reverse ./vids/axis={ax}/{src}_{dst}/res_all_reverse.mp4')
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/{m}/cond_reverse.mp4')
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/ball.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/ball_reverse.mp4')
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_reverse.mp4')

    # Time concatenation
    filter_cat = f'-filter_complex "[0:v][1:v]concat=n=2:v=1:a=0"'
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/res_all.mp4 -i ./vids/axis={ax}/{src}_{dst}/res_all_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/res_all_concat.mp4')
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/ball.mp4 -i ./vids/axis={ax}/{src}_{dst}/ball_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/ball_concat.mp4')
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/cond_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/{m}/cond_concat.mp4')
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_concat.mp4')

    # Copy the res_all.mp4 and ball.mp4 to ./vids/all_outputs/ and rename them with {src}_{dst}_{ax}.mp4
    os.system(f'cp /data/mint/DPM_Dataset/ffhq_256_with_anno/ffhq_256/valid/{src} ./vids/all_outputs/res/{src}')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/res_all_concat.mp4 ./vids/all_outputs/res/{src}_{dst}_{ax}.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/ball_concat.mp4 ./vids/all_outputs/res/{src}_{dst}_{ax}_ball.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/{m}/cond_concat.mp4 ./vids/all_outputs/misc/{src}_{dst}_{ax}_cond.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_concat.mp4 ./vids/all_outputs/misc/{src}_{dst}_{ax}_res+cond.mp4')
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# 60 60
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/res_all.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 3239 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 3235 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55e227474f80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55e227474f80] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x55e227474f80] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/60684.jpg_62386.jpg/res_all_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=     528kB time=00:00:02.37 bitrate=1822.1kbits/s speed=3.03x
# video:527kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.236245%
# [libx264 @ 0x55e227474f80] frame I:1     Avg QP:22.88  size: 84002
# [libx264 @ 0x55e227474f80] frame P:49    Avg QP:25.23  size:  9150
# [libx264 @ 0x55e227474f80] frame B:10    Avg QP:28.89  size:   665
# [libx264 @ 0x55e227474f80] consecutive B-frames: 70.0% 23.3%  0.0%  6.7%
# [libx264 @ 0x55e227474f80] mb I  I16..4:  5.4% 66.2% 28.3%
# [libx264 @ 0x55e227474f80] mb P  I16..4:  0.9%  2.8%  0.4%  P16..4: 44.2% 11.3%  6.6%  0.0%  0.0%    skip:33.8%
# [libx264 @ 0x55e227474f80] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 12.1%  0.5%  0.2%  direct: 1.3%  skip:85.7%  L0:35.6% L1:57.6% BI: 6.8%
# [libx264 @ 0x55e227474f80] 8x8 transform intra:67.4% inter:67.4%
# [libx264 @ 0x55e227474f80] coded y,uvDC,uvAC intra: 69.0% 73.8% 34.4% inter: 32.4% 26.9% 1.5%
# [libx264 @ 0x55e227474f80] i16 v,h,dc,p: 23% 17%  2% 58%
# [libx264 @ 0x55e227474f80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 14% 12%  7%  8% 11%  7% 10%  9%
# [libx264 @ 0x55e227474f80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 13% 13%  7%  9% 11%  7% 10%  7%
# [libx264 @ 0x55e227474f80] i8c dc,h,v,p: 52% 16% 24%  9%
# [libx264 @ 0x55e227474f80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55e227474f80] ref P L0: 59.5% 37.4%  2.0%  1.0%
# [libx264 @ 0x55e227474f80] ref B L0: 94.7%  4.6%  0.7%
# [libx264 @ 0x55e227474f80] ref B L1: 99.5%  0.5%
# [libx264 @ 0x55e227474f80] kb/s:1724.82
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 164 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 159 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x5629fe9ba1c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5629fe9ba1c0] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x5629fe9ba1c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/60684.jpg_62386.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x512, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   59 fps=0.0 q=-1.0 Lsize=      50kB time=00:00:02.33 bitrate= 175.2kbits/s speed=16.2x
# video:48kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.147524%
# [libx264 @ 0x5629fe9ba1c0] frame I:1     Avg QP:18.78  size:  3166
# [libx264 @ 0x5629fe9ba1c0] frame P:17    Avg QP:25.68  size:  1681
# [libx264 @ 0x5629fe9ba1c0] frame B:41    Avg QP:24.73  size:   417
# [libx264 @ 0x5629fe9ba1c0] consecutive B-frames:  3.4% 10.2%  5.1% 81.4%
# [libx264 @ 0x5629fe9ba1c0] mb I  I16..4: 27.1% 55.5% 17.4%
# [libx264 @ 0x5629fe9ba1c0] mb P  I16..4:  2.7% 10.7%  2.6%  P16..4:  9.8%  4.6%  2.2%  0.0%  0.0%    skip:67.5%
# [libx264 @ 0x5629fe9ba1c0] mb B  I16..4:  0.3%  0.2%  0.1%  B16..8:  6.4%  2.2%  1.2%  direct: 1.1%  skip:88.6%  L0:45.3% L1:49.6% BI: 5.1%
# [libx264 @ 0x5629fe9ba1c0] 8x8 transform intra:61.6% inter:36.2%
# [libx264 @ 0x5629fe9ba1c0] coded y,uvDC,uvAC intra: 33.2% 19.6% 0.1% inter: 3.8% 1.1% 0.0%
# [libx264 @ 0x5629fe9ba1c0] i16 v,h,dc,p: 61%  5%  6% 28%
# [libx264 @ 0x5629fe9ba1c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 22% 29%  3%  4%  6%  4%  5%  3%
# [libx264 @ 0x5629fe9ba1c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 18% 29%  5%  3%  5%  5%  5%  4%
# [libx264 @ 0x5629fe9ba1c0] i8c dc,h,v,p: 79%  7% 13%  0%
# [libx264 @ 0x5629fe9ba1c0] Weighted P-Frames: Y:23.5% UV:11.8%
# [libx264 @ 0x5629fe9ba1c0] ref P L0: 57.8% 20.1% 14.5%  5.4%  2.2%
# [libx264 @ 0x5629fe9ba1c0] ref B L0: 86.5% 10.0%  3.5%
# [libx264 @ 0x5629fe9ba1c0] ref B L1: 95.4%  4.6%
# [libx264 @ 0x5629fe9ba1c0] kb/s:158.94
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/ball.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 137 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 132 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55cb8d8b8fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55cb8d8b8fc0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55cb8d8b8fc0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/60684.jpg_62386.jpg/ball_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   59 fps=0.0 q=-1.0 Lsize=      28kB time=00:00:02.33 bitrate=  99.5kbits/s speed=18.6x
# video:27kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.709601%
# [libx264 @ 0x55cb8d8b8fc0] frame I:1     Avg QP:23.96  size:  1993
# [libx264 @ 0x55cb8d8b8fc0] frame P:20    Avg QP:24.76  size:   988
# [libx264 @ 0x55cb8d8b8fc0] frame B:38    Avg QP:18.22  size:   131
# [libx264 @ 0x55cb8d8b8fc0] consecutive B-frames:  1.7% 37.3%  0.0% 61.0%
# [libx264 @ 0x55cb8d8b8fc0] mb I  I16..4: 57.0% 21.1% 21.9%
# [libx264 @ 0x55cb8d8b8fc0] mb P  I16..4: 35.2%  8.1%  1.1%  P16..4: 27.1%  7.9%  3.3%  0.0%  0.0%    skip:17.3%
# [libx264 @ 0x55cb8d8b8fc0] mb B  I16..4:  1.2%  0.2%  0.0%  B16..8: 15.0%  0.8%  0.0%  direct: 0.1%  skip:82.7%  L0:37.8% L1:55.8% BI: 6.5%
# [libx264 @ 0x55cb8d8b8fc0] 8x8 transform intra:18.3% inter:63.6%
# [libx264 @ 0x55cb8d8b8fc0] coded y,uvDC,uvAC intra: 8.5% 24.2% 0.2% inter: 5.3% 4.7% 0.0%
# [libx264 @ 0x55cb8d8b8fc0] i16 v,h,dc,p:  8% 10%  1% 81%
# [libx264 @ 0x55cb8d8b8fc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 14% 12%  3% 12% 10%  8%  5%  2%
# [libx264 @ 0x55cb8d8b8fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 14% 33%  6%  5%  5%  5%  4%  1%
# [libx264 @ 0x55cb8d8b8fc0] i8c dc,h,v,p: 56% 20% 23%  2%
# [libx264 @ 0x55cb8d8b8fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55cb8d8b8fc0] ref P L0: 82.3% 11.8%  3.7%  2.1%
# [libx264 @ 0x55cb8d8b8fc0] ref B L0: 93.1%  5.8%  1.0%
# [libx264 @ 0x55cb8d8b8fc0] ref B L1: 98.3%  1.7%
# [libx264 @ 0x55cb8d8b8fc0] kb/s:87.07
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 598 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 594 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55b1a73fed00] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55b1a73fed00] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55b1a73fed00] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/60684.jpg_62386.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 384x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   59 fps=0.0 q=-1.0 Lsize=     104kB time=00:00:02.33 bitrate= 366.0kbits/s speed=9.85x
# video:103kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.212644%
# [libx264 @ 0x55b1a73fed00] frame I:1     Avg QP:22.71  size: 14281
# [libx264 @ 0x55b1a73fed00] frame P:48    Avg QP:25.42  size:  1841
# [libx264 @ 0x55b1a73fed00] frame B:10    Avg QP:30.07  size:   212
# [libx264 @ 0x55b1a73fed00] consecutive B-frames: 69.5% 23.7%  0.0%  6.8%
# [libx264 @ 0x55b1a73fed00] mb I  I16..4: 16.9% 48.7% 34.4%
# [libx264 @ 0x55b1a73fed00] mb P  I16..4:  0.4%  2.3%  0.5%  P16..4: 43.6% 10.3%  7.2%  0.0%  0.0%    skip:35.6%
# [libx264 @ 0x55b1a73fed00] mb B  I16..4:  0.1%  0.1%  0.1%  B16..8: 12.8%  1.0%  0.4%  direct: 1.9%  skip:83.7%  L0:42.5% L1:49.3% BI: 8.2%
# [libx264 @ 0x55b1a73fed00] 8x8 transform intra:62.5% inter:62.6%
# [libx264 @ 0x55b1a73fed00] coded y,uvDC,uvAC intra: 63.7% 59.0% 25.2% inter: 33.0% 23.7% 0.6%
# [libx264 @ 0x55b1a73fed00] i16 v,h,dc,p: 68%  8%  7% 16%
# [libx264 @ 0x55b1a73fed00] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 12% 19%  5%  9% 10%  7%  7%  7%
# [libx264 @ 0x55b1a73fed00] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 12% 19%  7%  8% 10%  7% 10%  7%
# [libx264 @ 0x55b1a73fed00] i8c dc,h,v,p: 57% 12% 24%  7%
# [libx264 @ 0x55b1a73fed00] Weighted P-Frames: Y:2.1% UV:0.0%
# [libx264 @ 0x55b1a73fed00] ref P L0: 58.3% 38.1%  2.3%  1.3%  0.1%
# [libx264 @ 0x55b1a73fed00] ref B L0: 90.0%  9.2%  0.8%
# [libx264 @ 0x55b1a73fed00] ref B L1: 99.1%  0.9%
# [libx264 @ 0x55b1a73fed00] kb/s:340.99
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/res_all.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 3239 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 3235 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/res_all_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 1731 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 1727 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x5643f124c880] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5643f124c880] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x5643f124c880] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/60684.jpg_62386.jpg/res_all_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  120 fps= 90 q=-1.0 Lsize=     974kB time=00:00:04.87 bitrate=1636.8kbits/s speed=3.67x
# video:972kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.168216%
# [libx264 @ 0x5643f124c880] frame I:1     Avg QP:23.48  size: 77840
# [libx264 @ 0x5643f124c880] frame P:99    Avg QP:24.77  size:  9145
# [libx264 @ 0x5643f124c880] frame B:20    Avg QP:28.74  size:   594
# [libx264 @ 0x5643f124c880] consecutive B-frames: 70.0% 23.3%  0.0%  6.7%
# [libx264 @ 0x5643f124c880] mb I  I16..4:  7.5% 60.9% 31.6%
# [libx264 @ 0x5643f124c880] mb P  I16..4:  0.9%  2.8%  0.4%  P16..4: 44.8% 11.4%  6.3%  0.0%  0.0%    skip:33.4%
# [libx264 @ 0x5643f124c880] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 11.3%  0.4%  0.2%  direct: 1.1%  skip:86.8%  L0:23.4% L1:69.7% BI: 6.9%
# [libx264 @ 0x5643f124c880] 8x8 transform intra:67.3% inter:67.0%
# [libx264 @ 0x5643f124c880] coded y,uvDC,uvAC intra: 64.6% 72.0% 25.7% inter: 31.7% 27.1% 1.4%
# [libx264 @ 0x5643f124c880] i16 v,h,dc,p: 24% 17%  2% 56%
# [libx264 @ 0x5643f124c880] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 14% 12%  7%  9% 12%  8%  9%  9%
# [libx264 @ 0x5643f124c880] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 13% 14%  7%  9% 11%  7%  9%  7%
# [libx264 @ 0x5643f124c880] i8c dc,h,v,p: 54% 15% 24%  7%
# [libx264 @ 0x5643f124c880] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5643f124c880] ref P L0: 62.5% 34.2%  2.1%  1.1%
# [libx264 @ 0x5643f124c880] ref B L0: 94.0%  5.3%  0.6%
# [libx264 @ 0x5643f124c880] ref B L1: 99.6%  0.4%
# [libx264 @ 0x5643f124c880] kb/s:1592.09
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/ball.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 137 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 132 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/ball_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 94 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 89 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55ff0a3c9780] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55ff0a3c9780] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55ff0a3c9780] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/60684.jpg_62386.jpg/ball_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  118 fps=0.0 q=-1.0 Lsize=      55kB time=00:00:04.79 bitrate=  94.8kbits/s speed=21.7x
# video:53kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.156811%
# [libx264 @ 0x55ff0a3c9780] frame I:1     Avg QP:22.81  size:  2030
# [libx264 @ 0x55ff0a3c9780] frame P:48    Avg QP:24.57  size:   918
# [libx264 @ 0x55ff0a3c9780] frame B:69    Avg QP:17.79  size:   112
# [libx264 @ 0x55ff0a3c9780] consecutive B-frames:  0.8% 62.7%  2.5% 33.9%
# [libx264 @ 0x55ff0a3c9780] mb I  I16..4: 55.5% 21.5% 23.0%
# [libx264 @ 0x55ff0a3c9780] mb P  I16..4: 30.3%  7.0%  0.7%  P16..4: 32.1%  7.4%  2.8%  0.0%  0.0%    skip:19.8%
# [libx264 @ 0x55ff0a3c9780] mb B  I16..4:  0.8%  0.1%  0.0%  B16..8: 13.1%  0.8%  0.0%  direct: 0.1%  skip:85.0%  L0:45.6% L1:48.0% BI: 6.3%
# [libx264 @ 0x55ff0a3c9780] 8x8 transform intra:18.4% inter:64.2%
# [libx264 @ 0x55ff0a3c9780] coded y,uvDC,uvAC intra: 6.8% 25.8% 0.1% inter: 6.0% 5.3% 0.0%
# [libx264 @ 0x55ff0a3c9780] i16 v,h,dc,p:  8% 10%  1% 81%
# [libx264 @ 0x55ff0a3c9780] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 17% 10%  3% 13% 10%  9%  5%  1%
# [libx264 @ 0x55ff0a3c9780] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 28% 20% 30%  6%  4%  4%  3%  4%  2%
# [libx264 @ 0x55ff0a3c9780] i8c dc,h,v,p: 57% 20% 22%  1%
# [libx264 @ 0x55ff0a3c9780] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55ff0a3c9780] ref P L0: 80.5% 10.0%  7.7%  1.8%
# [libx264 @ 0x55ff0a3c9780] ref B L0: 94.1%  5.5%  0.4%
# [libx264 @ 0x55ff0a3c9780] ref B L1: 99.4%  0.6%
# [libx264 @ 0x55ff0a3c9780] kb/s:87.62
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 164 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 159 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 166 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 161 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55a604e98fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55a604e98fc0] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x55a604e98fc0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/60684.jpg_62386.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x512, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  118 fps=0.0 q=-1.0 Lsize=      92kB time=00:00:04.79 bitrate= 157.1kbits/s speed=16.1x
# video:90kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.458963%
# [libx264 @ 0x55a604e98fc0] frame I:1     Avg QP:19.41  size:  3163
# [libx264 @ 0x55a604e98fc0] frame P:32    Avg QP:25.29  size:  1690
# [libx264 @ 0x55a604e98fc0] frame B:85    Avg QP:23.82  size:   399
# [libx264 @ 0x55a604e98fc0] consecutive B-frames:  1.7%  5.1%  5.1% 88.1%
# [libx264 @ 0x55a604e98fc0] mb I  I16..4: 14.6% 68.0% 17.4%
# [libx264 @ 0x55a604e98fc0] mb P  I16..4:  2.0%  9.4%  2.7%  P16..4:  9.6%  4.5%  2.5%  0.0%  0.0%    skip:69.3%
# [libx264 @ 0x55a604e98fc0] mb B  I16..4:  0.2%  0.1%  0.1%  B16..8:  6.6%  2.3%  1.1%  direct: 0.7%  skip:88.9%  L0:48.5% L1:46.9% BI: 4.6%
# [libx264 @ 0x55a604e98fc0] 8x8 transform intra:64.6% inter:32.3%
# [libx264 @ 0x55a604e98fc0] coded y,uvDC,uvAC intra: 40.0% 21.9% 0.1% inter: 3.2% 0.9% 0.0%
# [libx264 @ 0x55a604e98fc0] i16 v,h,dc,p: 49%  7%  6% 39%
# [libx264 @ 0x55a604e98fc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 15% 27%  3%  5%  7%  5%  6%  4%
# [libx264 @ 0x55a604e98fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 17% 31%  4%  4%  5%  5%  4%  4%
# [libx264 @ 0x55a604e98fc0] i8c dc,h,v,p: 76%  9% 14%  0%
# [libx264 @ 0x55a604e98fc0] Weighted P-Frames: Y:12.5% UV:3.1%
# [libx264 @ 0x55a604e98fc0] ref P L0: 61.2% 16.0% 13.6%  8.1%  1.2%
# [libx264 @ 0x55a604e98fc0] ref B L0: 84.5% 13.4%  2.2%
# [libx264 @ 0x55a604e98fc0] ref B L1: 96.3%  3.7%
# [libx264 @ 0x55a604e98fc0] kb/s:148.36
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 598 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 594 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 347 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 343 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f05da68540] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f05da68540] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55f05da68540] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/60684.jpg_62386.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 384x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  118 fps=0.0 q=-1.0 Lsize=     192kB time=00:00:04.79 bitrate= 328.0kbits/s speed=17.7x
# video:190kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.868311%
# [libx264 @ 0x55f05da68540] frame I:1     Avg QP:22.51  size: 13616
# [libx264 @ 0x55f05da68540] frame P:96    Avg QP:25.10  size:  1833
# [libx264 @ 0x55f05da68540] frame B:21    Avg QP:30.26  size:   215
# [libx264 @ 0x55f05da68540] consecutive B-frames: 69.5% 20.3%  0.0% 10.2%
# [libx264 @ 0x55f05da68540] mb I  I16..4: 18.2% 47.1% 34.6%
# [libx264 @ 0x55f05da68540] mb P  I16..4:  0.4%  2.2%  0.5%  P16..4: 43.9% 10.4%  6.5%  0.0%  0.0%    skip:36.0%
# [libx264 @ 0x55f05da68540] mb B  I16..4:  0.0%  0.3%  0.1%  B16..8: 12.6%  1.2%  0.5%  direct: 1.8%  skip:83.4%  L0:31.6% L1:59.8% BI: 8.6%
# [libx264 @ 0x55f05da68540] 8x8 transform intra:65.2% inter:62.7%
# [libx264 @ 0x55f05da68540] coded y,uvDC,uvAC intra: 63.6% 59.3% 19.0% inter: 31.7% 23.2% 0.6%
# [libx264 @ 0x55f05da68540] i16 v,h,dc,p: 59% 10%  5% 26%
# [libx264 @ 0x55f05da68540] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 12% 20%  5% 10% 11%  7%  8%  7%
# [libx264 @ 0x55f05da68540] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 13% 20%  6%  8%  9%  6%  9%  6%
# [libx264 @ 0x55f05da68540] i8c dc,h,v,p: 61% 12% 21%  6%
# [libx264 @ 0x55f05da68540] Weighted P-Frames: Y:1.0% UV:0.0%
# [libx264 @ 0x55f05da68540] ref P L0: 61.3% 35.6%  1.9%  1.2%  0.0%
# [libx264 @ 0x55f05da68540] ref B L0: 91.1%  7.9%  0.9%
# [libx264 @ 0x55f05da68540] ref B L1: 98.4%  1.6%
# [libx264 @ 0x55f05da68540] kb/s:315.75
#   6%|▋         | 1/16 [00:13<03:25, 13.68s/it]
# 60 60
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/res_all.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 3065 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 3061 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55bb62ac8540] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55bb62ac8540] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x55bb62ac8540] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/66744.jpg_60082.jpg/res_all_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# ...
# [libx264 @ 0x5614c4d631c0] consecutive B-frames:  5.1% 13.6%  0.0% 81.4%
# [libx264 @ 0x5614c4d631c0] mb I  I16..4: 14.1% 64.6% 21.3%
# [libx264 @ 0x5614c4d631c0] mb P  I16..4:  2.5%  6.6%  2.5%  P16..4: 11.1%  4.7%  2.1%  0.0%  0.0%    skip:70.4%
# [libx264 @ 0x5614c4d631c0] mb B  I16..4:  0.4%  0.1%  0.1%  B16..8:  8.3%  2.4%  0.9%  direct: 0.5%  skip:87.4%  L0:45.1% L1:50.6% BI: 4.3%
# [libx264 @ 0x5614c4d631c0] 8x8 transform intra:55.9% inter:33.6%
# [libx264 @ 0x5614c4d631c0] coded y,uvDC,uvAC intra: 31.8% 16.4% 0.0% inter: 3.5% 0.8% 0.0%
# [libx264 @ 0x5614c4d631c0] i16 v,h,dc,p: 41% 15%  7% 37%
# [libx264 @ 0x5614c4d631c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 35% 19% 23%  2%  5%  7%  4%  3%  3%
# [libx264 @ 0x5614c4d631c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 18% 27%  5%  4%  5%  4%  4%  3%
# [libx264 @ 0x5614c4d631c0] i8c dc,h,v,p: 76% 10% 14%  1%
# [libx264 @ 0x5614c4d631c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5614c4d631c0] ref P L0: 67.0% 22.2%  6.8%  3.9%
# [libx264 @ 0x5614c4d631c0] ref B L0: 84.4% 12.7%  2.9%
# [libx264 @ 0x5614c4d631c0] ref B L1: 97.0%  3.0%
# [libx264 @ 0x5614c4d631c0] kb/s:155.03
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/65233.jpg_65718.jpg/ball.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 134 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 129 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x555c6346b540] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x555c6346b540] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x555c6346b540] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/65233.jpg_65718.jpg/ball_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   59 fps=0.0 q=-1.0 Lsize=      28kB time=00:00:02.33 bitrate=  99.0kbits/s speed=14.6x
# video:27kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 5.736355%
# [libx264 @ 0x555c6346b540] frame I:1     Avg QP:23.19  size:  1820
# [libx264 @ 0x555c6346b540] frame P:20    Avg QP:23.81  size:  1021
# [libx264 @ 0x555c6346b540] frame B:38    Avg QP:17.59  size:   115
# [libx264 @ 0x555c6346b540] consecutive B-frames:  1.7% 37.3%  0.0% 61.0%
# [libx264 @ 0x555c6346b540] mb I  I16..4: 48.8% 27.7% 23.4%
# [libx264 @ 0x555c6346b540] mb P  I16..4: 30.5%  8.2%  2.2%  P16..4: 28.0%  8.1%  4.2%  0.0%  0.0%    skip:18.9%
# [libx264 @ 0x555c6346b540] mb B  I16..4:  1.6%  0.1%  0.0%  B16..8: 14.3%  0.5%  0.0%  direct: 0.1%  skip:83.4%  L0:39.9% L1:53.0% BI: 7.1%
# [libx264 @ 0x555c6346b540] 8x8 transform intra:19.9% inter:59.9%
# [libx264 @ 0x555c6346b540] coded y,uvDC,uvAC intra: 10.9% 18.6% 0.0% inter: 5.1% 2.8% 0.0%
# [libx264 @ 0x555c6346b540] i16 v,h,dc,p: 10% 13%  2% 75%
# [libx264 @ 0x555c6346b540] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 31% 24% 12%  4%  9%  7%  8%  4%  2%
# [libx264 @ 0x555c6346b540] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 22% 30%  5%  5%  3%  4%  3%  2%
# [libx264 @ 0x555c6346b540] i8c dc,h,v,p: 63% 17% 18%  1%
# [libx264 @ 0x555c6346b540] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x555c6346b540] ref P L0: 79.4% 13.6%  4.8%  2.2%
# [libx264 @ 0x555c6346b540] ref B L0: 91.4%  7.3%  1.3%
# [libx264 @ 0x555c6346b540] ref B L1: 99.2%  0.8%
# [libx264 @ 0x555c6346b540] kb/s:86.65
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/65233.jpg_65718.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 503 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 499 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55da8b0ca9c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55da8b0ca9c0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55da8b0ca9c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/65233.jpg_65718.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 384x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   59 fps=0.0 q=-1.0 Lsize=      91kB time=00:00:02.33 bitrate= 319.9kbits/s speed=13.9x
# video:90kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.416350%
# [libx264 @ 0x55da8b0ca9c0] frame I:1     Avg QP:23.03  size: 13251
# [libx264 @ 0x55da8b0ca9c0] frame P:47    Avg QP:24.23  size:  1599
# [libx264 @ 0x55da8b0ca9c0] frame B:11    Avg QP:30.23  size:   265
# [libx264 @ 0x55da8b0ca9c0] consecutive B-frames: 66.1% 27.1%  0.0%  6.8%
# [libx264 @ 0x55da8b0ca9c0] mb I  I16..4:  8.1% 58.1% 33.9%
# [libx264 @ 0x55da8b0ca9c0] mb P  I16..4:  1.2%  2.1%  0.6%  P16..4: 47.6%  8.1%  6.1%  0.0%  0.0%    skip:34.3%
# [libx264 @ 0x55da8b0ca9c0] mb B  I16..4:  0.1%  0.3%  0.0%  B16..8: 14.6%  1.3%  0.9%  direct: 1.8%  skip:81.0%  L0:33.2% L1:59.0% BI: 7.8%
# [libx264 @ 0x55da8b0ca9c0] 8x8 transform intra:56.4% inter:63.6%
# [libx264 @ 0x55da8b0ca9c0] coded y,uvDC,uvAC intra: 49.3% 52.6% 16.8% inter: 28.5% 21.8% 0.2%
# [libx264 @ 0x55da8b0ca9c0] i16 v,h,dc,p: 23% 34%  5% 38%
# [libx264 @ 0x55da8b0ca9c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 18% 31%  5%  7%  5%  7%  4%  6%
# [libx264 @ 0x55da8b0ca9c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 14% 22%  7%  6%  8%  5%  9%  5%
# [libx264 @ 0x55da8b0ca9c0] i8c dc,h,v,p: 57% 17% 18%  8%
# [libx264 @ 0x55da8b0ca9c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55da8b0ca9c0] ref P L0: 64.2% 31.8%  2.7%  1.2%
# [libx264 @ 0x55da8b0ca9c0] ref B L0: 91.5%  8.5%
# [libx264 @ 0x55da8b0ca9c0] ref B L1: 99.2%  0.8%
# [libx264 @ 0x55da8b0ca9c0] kb/s:297.14
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/65233.jpg_65718.jpg/res_all.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 2802 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 2797 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/65233.jpg_65718.jpg/res_all_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 1473 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 1468 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x558e9023f640] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x558e9023f640] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x558e9023f640] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/65233.jpg_65718.jpg/res_all_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=    1 fps=0.0 q=0.0 size=       0kB time=00:00:00.00 bitrate=N/A speed=   0x
