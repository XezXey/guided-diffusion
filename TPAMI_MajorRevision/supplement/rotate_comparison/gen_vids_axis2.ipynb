# %%
import json, os, glob, tqdm
from PIL import Image
import numpy as np
import subprocess

def sort_by_frame(path_list):
    frame_anno = []
    for p in path_list:
        frame_idx = os.path.splitext(p.split('/')[-1].split('_')[-1])[0][5:]   # 0-4 is "frame", so we used [5:] here
        frame_anno.append(int(frame_idx))
    sorted_idx = np.argsort(frame_anno)
    sorted_path_list = []
    for idx in sorted_idx:
      sorted_path_list.append(path_list[idx])
    return sorted_path_list

# %% [markdown]
# # FFHQ: RotateSH_axis2.json

# %%
ax = 2

method = ["hou21_rotate_axis=2", "hou22_rotate_axis=2", "diffusionrig_rotate_axis=2", "iclight_rotate_512x512_map_centered_axis2", "relipa_rotate_axis=2", "ours_256_difareli_rotate_rot2", "ours_difareli++_oneshot_rotate_rot2_tomax"]
# sample_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/experiment_scripts/TPAMI/sample_json/TPAMI_MajorRevision/rotateSH_axis2.json", "r"))
# sample_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/visualize_scripts/TPAMI/main_results/FFHQ_CastShadows/RotateSH_figures/sample_json_with_frameid/selected_rotate_RT.json", "r"))
sample_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/experiment_scripts/TPAMI/sample_json/TPAMI_MajorRevision/website.json", "r"))
meta_dat = json.load(open("/home/mint/Dev/DiFaReli/difareli-faster/visualize_scripts/TPAMI/MajorRevision/figure/ffhq/rotateSH_axis2.json", "r"))

os.makedirs("./vids/", exist_ok=True)
os.makedirs(f'./vids/all_outputs/res/', exist_ok=True)
os.makedirs(f'./vids/all_outputs/misc/', exist_ok=True)

no_f1 = True

for sample_id, sample in tqdm.tqdm(sample_dat['pair'].items()):
    src = sample['src']
    dst = sample['dst']
    for m in method:
        img_dir = meta_dat[m]['img_dir']
        n_frames = meta_dat[m]['n_frame']
        itp_method = meta_dat[m]['itp_method']
        diff_step = meta_dat[m]['diff_step']
        n_frame_tmp = meta_dat[m]['n_frame']
        os.makedirs(f'./vids/axis={ax}/{src}_{dst}/{m}/', exist_ok=True)
        if "hou21" in m or "hou22" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
        elif "iclight" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
        elif m == "diffusionrig_rotate_axis=2":
            img_path = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/n_frames={n_frame_tmp}/'
            relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:]
        elif m == "relipa_rotate_axis=2":
            img_path = f'{img_dir}/src={src}/dst={dst}/{itp_method}_{diff_step}/gs=4.5_ds=25/n_frames={n_frame_tmp}/256/'
            relit = sort_by_frame(glob.glob(f'{img_path}/res_frame*.png'))[1:]
        elif "difareli++" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
            shadow = sort_by_frame(glob.glob(f'{img_path}/dst_shadm_shad_f*.png'))[1:]
            render = sort_by_frame(glob.glob(f'{img_path}/dst_ren_f*.png'))[1:]
            for _, (s, r) in enumerate(zip(shadow, render)):
                i = int(s.split('/')[-1].split('frame')[-1].split('.')[0])
                assert i == int(r.split('/')[-1].split('frame')[-1].split('.')[0])
                os.system(f'cp {s} ./vids/axis={ax}/{src}_{dst}/{m}/dst_shadm_shad_frame_{i:04d}.png')
                os.system(f'cp {r} ./vids/axis={ax}/{src}_{dst}/{m}/dst_ren_frame_{i:04d}.png')

            assert len(relit) == len(shadow) == len(render)
            for j in range(len(relit)):
                r_tmp = np.array(Image.open(relit[j]))
                h, w, _ = r_tmp.shape
                s_tmp = np.array(Image.open(shadow[j]).resize((h//2, w//2)))
                ren_tmp = np.array(Image.open(render[j]).resize((h//2, w//2)))
                
                out_comb = np.concatenate((r_tmp, np.concatenate((ren_tmp, s_tmp), axis=0)), axis=1)
                Image.fromarray(out_comb).save(f'./vids/axis={ax}/{src}_{dst}/{m}/res+cond_frame_{j:04d}.png')
                
            cmds = [f'ffmpeg -y -r 24 -i ./vids/axis={ax}/{src}_{dst}/{m}/dst_shadm_shad_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/shadow.mp4',
                    f'ffmpeg -y -r 24 -i ./vids/axis={ax}/{src}_{dst}/{m}/dst_ren_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/render.mp4',
                    # Vertical stack them (render on top of shadow)
                    f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/render.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/shadow.mp4 -filter_complex vstack ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4',
                    f'ffmpeg -y -r 24 -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4'
            ]
            for c in cmds:
                try:
                    subprocess.run(c, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
                except subprocess.CalledProcessError as e:
                    print("An error occurred:", e)
        
        
            
        elif "difareli" in m:
            img_path = f'{img_dir}/src={src}/dst={dst}/Lerp_1000/n_frames={n_frames}/'
            relit = sort_by_frame(glob.glob(f'{img_path}/res_f*.png'))[1:]
        
        if len(relit) == 0:
            # Create 0 images for mockup and match the number of frames
            for i in range(1, int(n_frames)):
                img = Image.new('RGB', (256, 256), color='black')
                img.save(f'./vids/axis={ax}/{src}_{dst}/{m}/res_frame_{i:04d}.png')
            continue
        
        os.makedirs(f'./vids/axis={ax}/{src}_{dst}/{m}/', exist_ok=True)
        # Copy all images to a new folder
        for img in relit:
            i = int(img.split('/')[-1].split('frame')[-1].split('.')[0])
            os.system(f'cp {img} ./vids/axis={ax}/{src}_{dst}/{m}/res_frame_{i:04d}.png')
        
        #NOTE: Generate video high compression with 24 fps
        cmd = f'ffmpeg -y -r 24 -i ./vids/axis={ax}/{src}_{dst}/{m}/res_frame_%04d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/res_{m}.mp4'
        try:
            subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
        except subprocess.CalledProcessError as e:
            print("An error occurred:", e)


    # Copy the ball image
    # ttmp = glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_user_study/axis={ax}/valid/*_src={src}_dst={dst}")
    # ttmp = glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_user_study/axis={ax}/valid/*_src={src}_dst={dst}")
    # if len(ttmp) == 0:
    #     print(f"Cannot find the ball image for {src} to {dst} on axis {ax}")
    #     continue
    # ttmp = ttmp[0].split('/')[-1].replace(f'_src={src}_dst={dst}', '')
    # sample_id_revoke = ttmp
    # if sample_id != sample_id_revoke:
    #     ball = sorted(glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_user_study/axis={ax}/valid/{sample_id_revoke}_src={src}_dst={dst}/n_step={n_frames}/ball/m_*.png"))
    # else:
    # ball = sorted(glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_user_study/axis={ax}/valid/{sample_id}_src={src}_dst={dst}/n_step={n_frames}/ball/m_*.png"))
    ball = sorted(glob.glob(f"/data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_selected_rotateSH/axis={ax}/valid/{sample_id}_src={src}_dst={dst}/n_step={n_frames}/ball/m_*.png"))
    print(len(ball), int(n_frames))
    assert len(ball) == int(n_frames), f"Number of ball frames {len(ball)} does not match n_frames {n_frames} for {src} to {dst} on axis {ax}: /data/mint/DPM_Dataset/Dataset_For_Baseline/ffhq_selected_rotateSH/axis={ax}/valid/{sample_id}_src={src}_dst={dst}/n_step={n_frames}/ball/"
    if no_f1:
        ball = ball[1:]
    os.makedirs(f'./vids/axis={ax}/{src}_{dst}/ball/', exist_ok=True)
    for img in ball:
        os.system(f'cp {img} ./vids/axis={ax}/{src}_{dst}/ball/{img.split("/")[-1]}')

    cmd = f'ffmpeg -y -r 24 -i ./vids/axis={ax}/{src}_{dst}/ball/m_%03d.png -c:v libx264 -preset slow -crf 17 -vf fps=24 -pix_fmt yuv420p ./vids/axis={ax}/{src}_{dst}/ball.mp4'
    try:
        subprocess.run(cmd, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
    except subprocess.CalledProcessError as e:
        print("An error occurred:", e)

    # Concatenate all videos vertically following the method order
    video_list = []
    for m in method:
        if os.path.exists(f'./vids/axis={ax}/{src}_{dst}/res_{m}.mp4'):
            if "difareli++" in m:
                video_list.append(f'./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4')
            else:
                video_list.append(f'./vids/axis={ax}/{src}_{dst}/res_{m}.mp4')
    # video_list.append(f'./vids/axis={ax}/{src}_{dst}/ball.mp4')
    
    num_videos = len(video_list)
    # Generate FFmpeg inputs and filter_complex dynamically
    input_files = " ".join(f"-i {path}" for path in video_list)
    filter_complex = "".join(f"[{i}:v:0]" for i in range(num_videos)) + f"hstack=inputs={num_videos}"

    # Output file
    output_file = f"./vids/axis={ax}/{src}_{dst}/res_all.mp4"

    # Construct the FFmpeg command
    command = f"ffmpeg -y {input_files} -filter_complex \"{filter_complex}\" -c:v libx264 -crf 17 -preset slow {output_file}"

    # Execute the command
    try:
        subprocess.run(command, shell=True, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, check=True)
    except subprocess.CalledProcessError as e:
        print("An error occurred:", e)

    # Create the reverse video of res_all.mp4, ball.mp4 and cond.mp4
    os.system(f'ffmpeg -y -i {output_file} -vf reverse ./vids/axis={ax}/{src}_{dst}/res_all_reverse.mp4')
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/{m}/cond_reverse.mp4')
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/ball.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/ball_reverse.mp4')
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4 -vf reverse ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_reverse.mp4')

    # Time concatenation
    filter_cat = f'-filter_complex "[0:v][1:v]concat=n=2:v=1:a=0"'
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/res_all.mp4 -i ./vids/axis={ax}/{src}_{dst}/res_all_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/res_all_concat.mp4')
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/ball.mp4 -i ./vids/axis={ax}/{src}_{dst}/ball_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/ball_concat.mp4')
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/cond.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/cond_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/{m}/cond_concat.mp4')
    os.system(f'ffmpeg -y -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond.mp4 -i ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_reverse.mp4 {filter_cat} ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_concat.mp4')

    # Copy the res_all.mp4 and ball.mp4 to ./vids/all_outputs/ and rename them with {src}_{dst}_{ax}.mp4
    os.system(f'cp /data/mint/DPM_Dataset/ffhq_256_with_anno/ffhq_256/valid/{src} ./vids/all_outputs/res/{src}')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/res_all_concat.mp4 ./vids/all_outputs/res/{src}_{dst}_{ax}.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/ball_concat.mp4 ./vids/all_outputs/res/{src}_{dst}_{ax}_ball.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/{m}/cond_concat.mp4 ./vids/all_outputs/misc/{src}_{dst}_{ax}_cond.mp4')
    os.system(f'cp ./vids/axis={ax}/{src}_{dst}/{m}/res+cond_concat.mp4 ./vids/all_outputs/misc/{src}_{dst}_{ax}_res+cond.mp4')
# Out:
#   0%|          | 0/16 [00:00<?, ?it/s]
# 60 60
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/res_all.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 3065 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 3061 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55a1a7151540] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55a1a7151540] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x55a1a7151540] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/66744.jpg_60082.jpg/res_all_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=     502kB time=00:00:02.37 bitrate=1730.7kbits/s speed=3.37x
# video:501kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.220599%
# [libx264 @ 0x55a1a7151540] frame I:1     Avg QP:22.57  size: 87310
# [libx264 @ 0x55a1a7151540] frame P:58    Avg QP:24.58  size:  7318
# [libx264 @ 0x55a1a7151540] frame B:1     Avg QP:26.60  size:   242
# [libx264 @ 0x55a1a7151540] consecutive B-frames: 96.7%  3.3%  0.0%  0.0%
# [libx264 @ 0x55a1a7151540] mb I  I16..4:  4.7% 55.3% 40.1%
# [libx264 @ 0x55a1a7151540] mb P  I16..4:  0.5%  1.0%  0.2%  P16..4: 41.8%  9.8%  7.0%  0.0%  0.0%    skip:39.7%
# [libx264 @ 0x55a1a7151540] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8: 17.4%  0.0%  0.0%  direct: 0.0%  skip:82.6%  L0:92.8% L1: 6.6% BI: 0.6%
# [libx264 @ 0x55a1a7151540] 8x8 transform intra:57.0% inter:64.0%
# [libx264 @ 0x55a1a7151540] coded y,uvDC,uvAC intra: 68.9% 72.1% 35.1% inter: 34.0% 23.5% 0.6%
# [libx264 @ 0x55a1a7151540] i16 v,h,dc,p: 18% 22%  3% 58%
# [libx264 @ 0x55a1a7151540] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 21% 12%  5% 10% 10% 10%  7%  8%
# [libx264 @ 0x55a1a7151540] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 21% 13%  6%  7% 10%  7%  7%  8%
# [libx264 @ 0x55a1a7151540] i8c dc,h,v,p: 50% 21% 22%  7%
# [libx264 @ 0x55a1a7151540] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55a1a7151540] ref P L0: 66.6% 30.7%  2.1%  0.7%
# [libx264 @ 0x55a1a7151540] kb/s:1638.42
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 166 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 161 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x565454cb41c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x565454cb41c0] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x565454cb41c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/66744.jpg_60082.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x512, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   59 fps=0.0 q=-1.0 Lsize=      49kB time=00:00:02.33 bitrate= 173.5kbits/s speed=16.5x
# video:48kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.145128%
# [libx264 @ 0x565454cb41c0] frame I:1     Avg QP:21.32  size:  3738
# [libx264 @ 0x565454cb41c0] frame P:17    Avg QP:25.17  size:  1672
# [libx264 @ 0x565454cb41c0] frame B:41    Avg QP:23.93  size:   395
# [libx264 @ 0x565454cb41c0] consecutive B-frames:  3.4%  6.8% 15.3% 74.6%
# [libx264 @ 0x565454cb41c0] mb I  I16..4: 14.3% 64.1% 21.7%
# [libx264 @ 0x565454cb41c0] mb P  I16..4:  1.8%  7.0%  2.4%  P16..4: 10.4%  5.6%  2.4%  0.0%  0.0%    skip:70.4%
# [libx264 @ 0x565454cb41c0] mb B  I16..4:  0.2%  0.1%  0.1%  B16..8:  7.8%  2.4%  1.0%  direct: 0.6%  skip:87.8%  L0:46.1% L1:49.2% BI: 4.8%
# [libx264 @ 0x565454cb41c0] 8x8 transform intra:61.7% inter:35.4%
# [libx264 @ 0x565454cb41c0] coded y,uvDC,uvAC intra: 38.2% 8.3% 0.0% inter: 3.7% 0.2% 0.0%
# [libx264 @ 0x565454cb41c0] i16 v,h,dc,p: 46% 11%  9% 35%
# [libx264 @ 0x565454cb41c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 14% 29%  4%  5%  8%  4%  6%  4%
# [libx264 @ 0x565454cb41c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 17% 30%  4%  4%  5%  5%  4%  4%
# [libx264 @ 0x565454cb41c0] i8c dc,h,v,p: 81%  7% 12%  0%
# [libx264 @ 0x565454cb41c0] Weighted P-Frames: Y:5.9% UV:0.0%
# [libx264 @ 0x565454cb41c0] ref P L0: 72.1% 13.2%  9.2%  5.2%  0.3%
# [libx264 @ 0x565454cb41c0] ref B L0: 81.0% 16.0%  3.0%
# [libx264 @ 0x565454cb41c0] ref B L1: 96.4%  3.6%
# [libx264 @ 0x565454cb41c0] kb/s:157.41
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/ball.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 119 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 114 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x55b59d213fc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55b59d213fc0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55b59d213fc0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/66744.jpg_60082.jpg/ball_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   59 fps=0.0 q=-1.0 Lsize=      26kB time=00:00:02.33 bitrate=  91.5kbits/s speed=13.9x
# video:25kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 6.234831%
# [libx264 @ 0x55b59d213fc0] frame I:1     Avg QP:22.79  size:  1902
# [libx264 @ 0x55b59d213fc0] frame P:22    Avg QP:24.10  size:   861
# [libx264 @ 0x55b59d213fc0] frame B:36    Avg QP:16.76  size:   100
# [libx264 @ 0x55b59d213fc0] consecutive B-frames:  1.7% 50.8%  0.0% 47.5%
# [libx264 @ 0x55b59d213fc0] mb I  I16..4: 55.5% 22.3% 22.3%
# [libx264 @ 0x55b59d213fc0] mb P  I16..4: 33.2%  6.2%  1.0%  P16..4: 30.0%  6.7%  2.5%  0.0%  0.0%    skip:20.4%
# [libx264 @ 0x55b59d213fc0] mb B  I16..4:  1.2%  0.2%  0.0%  B16..8: 10.9%  0.5%  0.0%  direct: 0.0%  skip:87.0%  L0:44.8% L1:48.1% BI: 7.1%
# [libx264 @ 0x55b59d213fc0] 8x8 transform intra:16.0% inter:60.5%
# [libx264 @ 0x55b59d213fc0] coded y,uvDC,uvAC intra: 7.0% 9.7% 0.0% inter: 5.5% 1.4% 0.0%
# [libx264 @ 0x55b59d213fc0] i16 v,h,dc,p:  9%  9%  2% 80%
# [libx264 @ 0x55b59d213fc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 32% 24% 15%  3%  8%  6%  5%  4%  2%
# [libx264 @ 0x55b59d213fc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 24% 31%  5%  6%  4%  5%  2%  2%
# [libx264 @ 0x55b59d213fc0] i8c dc,h,v,p: 75% 12% 12%  1%
# [libx264 @ 0x55b59d213fc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55b59d213fc0] ref P L0: 87.4%  6.7%  3.7%  2.2%
# [libx264 @ 0x55b59d213fc0] ref B L0: 91.7%  6.6%  1.6%
# [libx264 @ 0x55b59d213fc0] ref B L1: 97.9%  2.1%
# [libx264 @ 0x55b59d213fc0] kb/s:79.55
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 529 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 525 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x561f3a0989c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x561f3a0989c0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x561f3a0989c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/66744.jpg_60082.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 384x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   59 fps=0.0 q=-1.0 Lsize=      93kB time=00:00:02.33 bitrate= 326.3kbits/s speed=17.9x
# video:92kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.327811%
# [libx264 @ 0x561f3a0989c0] frame I:1     Avg QP:22.22  size: 14684
# [libx264 @ 0x561f3a0989c0] frame P:50    Avg QP:24.80  size:  1543
# [libx264 @ 0x561f3a0989c0] frame B:8     Avg QP:29.90  size:   175
# [libx264 @ 0x561f3a0989c0] consecutive B-frames: 76.3% 16.9%  0.0%  6.8%
# [libx264 @ 0x561f3a0989c0] mb I  I16..4: 14.8% 45.3% 39.8%
# [libx264 @ 0x561f3a0989c0] mb P  I16..4:  0.2%  1.1%  0.3%  P16..4: 41.7%  9.7%  6.8%  0.0%  0.0%    skip:40.2%
# [libx264 @ 0x561f3a0989c0] mb B  I16..4:  0.0%  0.2%  0.0%  B16..8: 10.7%  0.8%  0.6%  direct: 1.4%  skip:86.3%  L0:36.5% L1:57.7% BI: 5.9%
# [libx264 @ 0x561f3a0989c0] 8x8 transform intra:56.2% inter:61.9%
# [libx264 @ 0x561f3a0989c0] coded y,uvDC,uvAC intra: 68.7% 60.3% 29.2% inter: 30.3% 18.2% 0.3%
# [libx264 @ 0x561f3a0989c0] i16 v,h,dc,p: 72%  6% 15%  6%
# [libx264 @ 0x561f3a0989c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 15% 19%  5% 11% 10%  7%  6%  9%
# [libx264 @ 0x561f3a0989c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 22% 19% 20%  6%  5%  8%  6%  7%  7%
# [libx264 @ 0x561f3a0989c0] i8c dc,h,v,p: 62% 15% 17%  6%
# [libx264 @ 0x561f3a0989c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x561f3a0989c0] ref P L0: 65.2% 33.1%  1.3%  0.5%
# [libx264 @ 0x561f3a0989c0] ref B L0: 93.0%  6.4%  0.6%
# [libx264 @ 0x561f3a0989c0] ref B L1: 99.2%  0.8%
# [libx264 @ 0x561f3a0989c0] kb/s:303.38
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/res_all.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 3065 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 3061 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/res_all_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 1644 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 1640 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55add0f4b640] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55add0f4b640] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x55add0f4b640] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/66744.jpg_60082.jpg/res_all_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  120 fps=100 q=-1.0 Lsize=     919kB time=00:00:04.87 bitrate=1545.0kbits/s speed=4.06x
# video:918kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.147533%
# [libx264 @ 0x55add0f4b640] frame I:1     Avg QP:23.16  size: 83528
# [libx264 @ 0x55add0f4b640] frame P:117   Avg QP:24.16  size:  7313
# [libx264 @ 0x55add0f4b640] frame B:2     Avg QP:26.58  size:   164
# [libx264 @ 0x55add0f4b640] consecutive B-frames: 96.7%  3.3%  0.0%  0.0%
# [libx264 @ 0x55add0f4b640] mb I  I16..4:  4.4% 53.4% 42.1%
# [libx264 @ 0x55add0f4b640] mb P  I16..4:  0.4%  0.9%  0.1%  P16..4: 43.0%  9.8%  6.7%  0.0%  0.0%    skip:39.0%
# [libx264 @ 0x55add0f4b640] mb B  I16..4:  0.0%  0.0%  0.0%  B16..8:  8.9%  0.0%  0.0%  direct: 0.0%  skip:91.1%  L0: 5.0% L1:94.7% BI: 0.3%
# [libx264 @ 0x55add0f4b640] 8x8 transform intra:58.7% inter:63.7%
# [libx264 @ 0x55add0f4b640] coded y,uvDC,uvAC intra: 62.5% 69.2% 24.7% inter: 32.7% 24.0% 0.6%
# [libx264 @ 0x55add0f4b640] i16 v,h,dc,p: 15% 23%  4% 57%
# [libx264 @ 0x55add0f4b640] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 17% 19% 13%  5% 10% 11% 10%  7%  8%
# [libx264 @ 0x55add0f4b640] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 21% 21% 14%  6%  7% 10%  7%  6%  7%
# [libx264 @ 0x55add0f4b640] i8c dc,h,v,p: 54% 19% 22%  5%
# [libx264 @ 0x55add0f4b640] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55add0f4b640] ref P L0: 64.2% 32.9%  2.1%  0.8%
# [libx264 @ 0x55add0f4b640] ref B L0: 94.4%  5.6%
# [libx264 @ 0x55add0f4b640] kb/s:1503.10
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/ball.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 119 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 114 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/ball_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 86 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 81 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x5579855ebf80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x5579855ebf80] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x5579855ebf80] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/66744.jpg_60082.jpg/ball_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  118 fps=0.0 q=-1.0 Lsize=      52kB time=00:00:04.79 bitrate=  89.1kbits/s speed=30.3x
# video:50kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 4.434403%
# [libx264 @ 0x5579855ebf80] frame I:1     Avg QP:23.04  size:  1906
# [libx264 @ 0x5579855ebf80] frame P:55    Avg QP:23.93  size:   807
# [libx264 @ 0x5579855ebf80] frame B:62    Avg QP:15.32  size:    67
# [libx264 @ 0x5579855ebf80] consecutive B-frames:  0.8% 86.4%  2.5% 10.2%
# [libx264 @ 0x5579855ebf80] mb I  I16..4: 48.4% 30.1% 21.5%
# [libx264 @ 0x5579855ebf80] mb P  I16..4: 27.0%  4.7%  0.5%  P16..4: 34.3%  7.9%  2.9%  0.0%  0.0%    skip:22.7%
# [libx264 @ 0x5579855ebf80] mb B  I16..4:  1.2%  0.1%  0.0%  B16..8:  7.5%  0.3%  0.0%  direct: 0.0%  skip:91.0%  L0:36.5% L1:58.3% BI: 5.2%
# [libx264 @ 0x5579855ebf80] 8x8 transform intra:15.1% inter:61.7%
# [libx264 @ 0x5579855ebf80] coded y,uvDC,uvAC intra: 5.7% 9.9% 0.0% inter: 6.1% 1.8% 0.0%
# [libx264 @ 0x5579855ebf80] i16 v,h,dc,p:  9%  9%  2% 80%
# [libx264 @ 0x5579855ebf80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 34% 23% 14%  3%  9%  6%  6%  5%  2%
# [libx264 @ 0x5579855ebf80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 26% 19% 36%  3%  4%  4%  4%  3%  2%
# [libx264 @ 0x5579855ebf80] i8c dc,h,v,p: 76% 12% 12%  0%
# [libx264 @ 0x5579855ebf80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x5579855ebf80] ref P L0: 83.5%  8.8%  6.2%  1.5%
# [libx264 @ 0x5579855ebf80] ref B L0: 89.2% 10.1%  0.7%
# [libx264 @ 0x5579855ebf80] ref B L1: 99.7%  0.3%
# [libx264 @ 0x5579855ebf80] kb/s:82.06
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 166 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 161 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 164 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 159 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55f04c636700] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55f04c636700] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x55f04c636700] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/66744.jpg_60082.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x512, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  118 fps=0.0 q=-1.0 Lsize=      92kB time=00:00:04.79 bitrate= 156.4kbits/s speed=34.2x
# video:89kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.452304%
# [libx264 @ 0x55f04c636700] frame I:1     Avg QP:21.24  size:  3586
# [libx264 @ 0x55f04c636700] frame P:36    Avg QP:24.54  size:  1587
# [libx264 @ 0x55f04c636700] frame B:81    Avg QP:22.97  size:   371
# [libx264 @ 0x55f04c636700] consecutive B-frames:  3.4% 11.9% 10.2% 74.6%
# [libx264 @ 0x55f04c636700] mb I  I16..4: 14.3% 64.5% 21.3%
# [libx264 @ 0x55f04c636700] mb P  I16..4:  1.7%  6.3%  2.0%  P16..4: 11.0%  5.5%  2.7%  0.0%  0.0%    skip:70.8%
# [libx264 @ 0x55f04c636700] mb B  I16..4:  0.2%  0.1%  0.1%  B16..8:  7.2%  2.3%  1.0%  direct: 0.6%  skip:88.7%  L0:44.2% L1:51.2% BI: 4.6%
# [libx264 @ 0x55f04c636700] 8x8 transform intra:61.1% inter:35.8%
# [libx264 @ 0x55f04c636700] coded y,uvDC,uvAC intra: 41.2% 10.5% 0.0% inter: 3.7% 0.2% 0.0%
# [libx264 @ 0x55f04c636700] i16 v,h,dc,p: 45% 14%  6% 35%
# [libx264 @ 0x55f04c636700] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27% 13% 23%  4%  6%  9%  5%  8%  4%
# [libx264 @ 0x55f04c636700] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 18% 32%  4%  4%  5%  5%  4%  3%
# [libx264 @ 0x55f04c636700] i8c dc,h,v,p: 78%  8% 13%  0%
# [libx264 @ 0x55f04c636700] Weighted P-Frames: Y:5.6% UV:0.0%
# [libx264 @ 0x55f04c636700] ref P L0: 64.3% 17.6%  9.7%  8.1%  0.2%
# [libx264 @ 0x55f04c636700] ref B L0: 84.2% 12.9%  2.9%
# [libx264 @ 0x55f04c636700] ref B L1: 96.3%  3.7%
# [libx264 @ 0x55f04c636700] kb/s:147.70
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 529 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 525 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/66744.jpg_60082.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 309 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 305 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55dd676eac80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55dd676eac80] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55dd676eac80] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/66744.jpg_60082.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 384x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  118 fps=0.0 q=-1.0 Lsize=     170kB time=00:00:04.79 bitrate= 290.6kbits/s speed=21.6x
# video:168kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 0.943681%
# [libx264 @ 0x55dd676eac80] frame I:1     Avg QP:22.65  size: 14816
# [libx264 @ 0x55dd676eac80] frame P:102   Avg QP:24.46  size:  1514
# [libx264 @ 0x55dd676eac80] frame B:15    Avg QP:29.91  size:   162
# [libx264 @ 0x55dd676eac80] consecutive B-frames: 76.3% 20.3%  0.0%  3.4%
# [libx264 @ 0x55dd676eac80] mb I  I16..4: 11.5% 45.6% 43.0%
# [libx264 @ 0x55dd676eac80] mb P  I16..4:  0.1%  1.0%  0.3%  P16..4: 42.7%  9.7%  6.0%  0.0%  0.0%    skip:40.2%
# [libx264 @ 0x55dd676eac80] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 12.0%  0.9%  0.6%  direct: 1.0%  skip:85.4%  L0:19.5% L1:74.5% BI: 6.0%
# [libx264 @ 0x55dd676eac80] 8x8 transform intra:61.5% inter:60.1%
# [libx264 @ 0x55dd676eac80] coded y,uvDC,uvAC intra: 67.3% 55.7% 21.0% inter: 29.6% 19.0% 0.3%
# [libx264 @ 0x55dd676eac80] i16 v,h,dc,p: 65% 14% 11% 11%
# [libx264 @ 0x55dd676eac80] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 16% 11% 23%  6% 10% 11%  8%  7%  9%
# [libx264 @ 0x55dd676eac80] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 23% 17% 21%  6%  7%  9%  6%  6%  6%
# [libx264 @ 0x55dd676eac80] i8c dc,h,v,p: 62% 14% 17%  6%
# [libx264 @ 0x55dd676eac80] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55dd676eac80] ref P L0: 63.9% 33.9%  1.5%  0.8%
# [libx264 @ 0x55dd676eac80] ref B L0: 90.0% 10.0%
# [libx264 @ 0x55dd676eac80] kb/s:279.41
#   6%|▋         | 1/16 [00:13<03:19, 13.28s/it]
# 60 60
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/60684.jpg_62386.jpg/res_all.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.50, start: 0.000000, bitrate: 3239 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 1920x256, 3235 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 -> #0:0 (h264 (native) -> h264 (libx264))
# Press [q] to stop, [?] for help
# [libx264 @ 0x562b5feeef80] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x562b5feeef80] profile High, level 3.1, 4:2:0, 8-bit
# [libx264 @ 0x562b5feeef80] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/60684.jpg_62386.jpg/res_all_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0(und): Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 1920x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=   60 fps=0.0 q=-1.0 Lsize=     528kB time=00:00:02.37 bitrate=1822.1kbits/s speed=3.66x
# ...
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/61234.jpg_64857.jpg/ball.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 144 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 139 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/61234.jpg_64857.jpg/ball_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 102 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x256, 97 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55e0d6be96c0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55e0d6be96c0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55e0d6be96c0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/61234.jpg_64857.jpg/ball_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  118 fps=0.0 q=-1.0 Lsize=      60kB time=00:00:04.79 bitrate= 102.8kbits/s speed=26.5x
# video:58kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 3.822225%
# [libx264 @ 0x55e0d6be96c0] frame I:1     Avg QP:23.18  size:  1863
# [libx264 @ 0x55e0d6be96c0] frame P:48    Avg QP:24.85  size:  1014
# [libx264 @ 0x55e0d6be96c0] frame B:69    Avg QP:19.12  size:   117
# [libx264 @ 0x55e0d6be96c0] consecutive B-frames:  0.8% 62.7%  2.5% 33.9%
# [libx264 @ 0x55e0d6be96c0] mb I  I16..4: 53.9% 23.0% 23.0%
# [libx264 @ 0x55e0d6be96c0] mb P  I16..4: 27.7%  7.1%  1.6%  P16..4: 33.1%  8.6%  3.3%  0.0%  0.0%    skip:18.6%
# [libx264 @ 0x55e0d6be96c0] mb B  I16..4:  1.1%  0.1%  0.0%  B16..8: 12.8%  0.8%  0.1%  direct: 0.1%  skip:85.0%  L0:43.9% L1:49.0% BI: 7.1%
# [libx264 @ 0x55e0d6be96c0] 8x8 transform intra:19.2% inter:62.6%
# [libx264 @ 0x55e0d6be96c0] coded y,uvDC,uvAC intra: 9.1% 20.8% 0.0% inter: 6.3% 3.8% 0.0%
# [libx264 @ 0x55e0d6be96c0] i16 v,h,dc,p:  8%  8%  2% 82%
# [libx264 @ 0x55e0d6be96c0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 19% 10%  3% 13% 10%  9%  4%  1%
# [libx264 @ 0x55e0d6be96c0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 29% 18% 29%  7%  3%  4%  3%  4%  2%
# [libx264 @ 0x55e0d6be96c0] i8c dc,h,v,p: 63% 18% 19%  1%
# [libx264 @ 0x55e0d6be96c0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55e0d6be96c0] ref P L0: 80.6%  8.7%  7.9%  2.8%
# [libx264 @ 0x55e0d6be96c0] ref B L0: 91.4%  7.6%  1.0%
# [libx264 @ 0x55e0d6be96c0] ref B L1: 99.3%  0.7%
# [libx264 @ 0x55e0d6be96c0] kb/s:95.38
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 158 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 153 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 155 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 256x512, 150 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x56451022a100] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x56451022a100] profile High, level 2.1, 4:2:0, 8-bit
# [libx264 @ 0x56451022a100] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=16 lookahead_threads=2 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/cond_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 256x512, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  118 fps=0.0 q=-1.0 Lsize=      88kB time=00:00:04.79 bitrate= 150.2kbits/s speed=25.3x
# video:86kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 2.575445%
# [libx264 @ 0x56451022a100] frame I:1     Avg QP:18.41  size:  3082
# [libx264 @ 0x56451022a100] frame P:38    Avg QP:25.31  size:  1587
# [libx264 @ 0x56451022a100] frame B:79    Avg QP:22.94  size:   299
# [libx264 @ 0x56451022a100] consecutive B-frames:  5.1% 16.9%  0.0% 78.0%
# [libx264 @ 0x56451022a100] mb I  I16..4: 14.8% 68.8% 16.4%
# [libx264 @ 0x56451022a100] mb P  I16..4:  1.3%  7.0%  2.0%  P16..4: 10.1%  5.2%  2.3%  0.0%  0.0%    skip:72.0%
# [libx264 @ 0x56451022a100] mb B  I16..4:  0.4%  0.1%  0.1%  B16..8:  6.0%  1.6%  0.6%  direct: 0.7%  skip:90.5%  L0:46.7% L1:48.2% BI: 5.1%
# [libx264 @ 0x56451022a100] 8x8 transform intra:63.4% inter:40.8%
# [libx264 @ 0x56451022a100] coded y,uvDC,uvAC intra: 45.4% 22.7% 0.0% inter: 3.6% 0.7% 0.0%
# [libx264 @ 0x56451022a100] i16 v,h,dc,p: 53%  6%  6% 35%
# [libx264 @ 0x56451022a100] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 25% 16% 20%  5%  6%  7%  7%  9%  5%
# [libx264 @ 0x56451022a100] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 24% 21% 27%  4%  5%  5%  6%  5%  3%
# [libx264 @ 0x56451022a100] i8c dc,h,v,p: 74% 11% 16%  0%
# [libx264 @ 0x56451022a100] Weighted P-Frames: Y:15.8% UV:0.0%
# [libx264 @ 0x56451022a100] ref P L0: 63.7% 16.0% 12.6%  7.0%  0.7%
# [libx264 @ 0x56451022a100] ref B L0: 82.8% 13.4%  3.7%
# [libx264 @ 0x56451022a100] ref B L1: 95.9%  4.1%
# [libx264 @ 0x56451022a100] kb/s:141.60
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
#   configuration: --prefix=/usr --extra-version=0ubuntu0.22.04.1 --toolchain=hardened --libdir=/usr/lib/x86_64-linux-gnu --incdir=/usr/include/x86_64-linux-gnu --arch=amd64 --enable-gpl --disable-stripping --enable-gnutls --enable-ladspa --enable-libaom --enable-libass --enable-libbluray --enable-libbs2b --enable-libcaca --enable-libcdio --enable-libcodec2 --enable-libdav1d --enable-libflite --enable-libfontconfig --enable-libfreetype --enable-libfribidi --enable-libgme --enable-libgsm --enable-libjack --enable-libmp3lame --enable-libmysofa --enable-libopenjpeg --enable-libopenmpt --enable-libopus --enable-libpulse --enable-librabbitmq --enable-librubberband --enable-libshine --enable-libsnappy --enable-libsoxr --enable-libspeex --enable-libsrt --enable-libssh --enable-libtheora --enable-libtwolame --enable-libvidstab --enable-libvorbis --enable-libvpx --enable-libwebp --enable-libx265 --enable-libxml2 --enable-libxvid --enable-libzimg --enable-libzmq --enable-libzvbi --enable-lv2 --enable-omx --enable-openal --enable-opencl --enable-opengl --enable-sdl2 --enable-pocketsphinx --enable-librsvg --enable-libmfx --enable-libdc1394 --enable-libdrm --enable-libiec61883 --enable-chromaprint --enable-frei0r --enable-libx264 --enable-shared
#   libavutil      56. 70.100 / 56. 70.100
#   libavcodec     58.134.100 / 58.134.100
#   libavformat    58. 76.100 / 58. 76.100
#   libavdevice    58. 13.100 / 58. 13.100
#   libavfilter     7.110.100 /  7.110.100
#   libswscale      5.  9.100 /  5.  9.100
#   libswresample   3.  9.100 /  3.  9.100
#   libpostproc    55.  9.100 / 55.  9.100
# Input #0, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 498 kb/s
#   Stream #0:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 494 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Input #1, mov,mp4,m4a,3gp,3g2,mj2, from './vids/axis=2/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond_reverse.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Duration: 00:00:02.46, start: 0.000000, bitrate: 283 kb/s
#   Stream #1:0(und): Video: h264 (High) (avc1 / 0x31637661), yuv420p, 384x256, 279 kb/s, 24 fps, 24 tbr, 12288 tbn, 48 tbc (default)
#     Metadata:
#       handler_name    : VideoHandler
#       vendor_id       : [0][0][0][0]
# Stream mapping:
#   Stream #0:0 (h264) -> concat:in0:v0
#   Stream #1:0 (h264) -> concat:in1:v0
#   concat -> Stream #0:0 (libx264)
# Press [q] to stop, [?] for help
# [libx264 @ 0x55920db70dc0] using cpu capabilities: MMX2 SSE2Fast SSSE3 SSE4.2 AVX FMA3 BMI2 AVX2
# [libx264 @ 0x55920db70dc0] profile High, level 1.3, 4:2:0, 8-bit
# [libx264 @ 0x55920db70dc0] 264 - core 163 r3060 5db6aa6 - H.264/MPEG-4 AVC codec - Copyleft 2003-2021 - http://www.videolan.org/x264.html - options: cabac=1 ref=3 deblock=1:0:0 analyse=0x3:0x113 me=hex subme=7 psy=1 psy_rd=1.00:0.00 mixed_ref=1 me_range=16 chroma_me=1 trellis=1 8x8dct=1 cqm=0 deadzone=21,11 fast_pskip=1 chroma_qp_offset=-2 threads=8 lookahead_threads=1 sliced_threads=0 nr=0 decimate=1 interlaced=0 bluray_compat=0 constrained_intra=0 bframes=3 b_pyramid=2 b_adapt=1 b_bias=0 direct=1 weightb=1 open_gop=0 weightp=2 keyint=250 keyint_min=24 scenecut=40 intra_refresh=0 rc_lookahead=40 rc=crf mbtree=1 crf=23.0 qcomp=0.60 qpmin=0 qpmax=69 qpstep=4 ip_ratio=1.40 aq=1:1.00
# Output #0, mp4, to './vids/axis=2/61234.jpg_64857.jpg/ours_difareli++_oneshot_rotate_rot2_tomax/res+cond_concat.mp4':
#   Metadata:
#     major_brand     : isom
#     minor_version   : 512
#     compatible_brands: isomiso2avc1mp41
#     encoder         : Lavf58.76.100
#   Stream #0:0: Video: h264 (avc1 / 0x31637661), yuv420p(progressive), 384x256, q=2-31, 24 fps, 12288 tbn (default)
#     Metadata:
#       encoder         : Lavc58.134.100 libx264
#     Side data:
#       cpb: bitrate max/min/avg: 0/0/0 buffer size: 0 vbv_delay: N/A
# frame=  118 fps=0.0 q=-1.0 Lsize=     158kB time=00:00:04.79 bitrate= 269.7kbits/s speed=18.7x
# video:156kB audio:0kB subtitle:0kB other streams:0kB global headers:0kB muxing overhead: 1.068157%
# [libx264 @ 0x55920db70dc0] frame I:1     Avg QP:22.02  size:  8979
# [libx264 @ 0x55920db70dc0] frame P:89    Avg QP:24.79  size:  1636
# [libx264 @ 0x55920db70dc0] frame B:28    Avg QP:28.59  size:   162
# [libx264 @ 0x55920db70dc0] consecutive B-frames: 66.1%  6.8%  0.0% 27.1%
# [libx264 @ 0x55920db70dc0] mb I  I16..4: 17.7% 46.9% 35.4%
# [libx264 @ 0x55920db70dc0] mb P  I16..4:  0.7%  2.5%  0.6%  P16..4: 38.1%  9.8%  5.7%  0.0%  0.0%    skip:42.6%
# [libx264 @ 0x55920db70dc0] mb B  I16..4:  0.0%  0.1%  0.0%  B16..8: 14.0%  0.8%  0.3%  direct: 1.1%  skip:83.7%  L0:30.6% L1:64.0% BI: 5.4%
# [libx264 @ 0x55920db70dc0] 8x8 transform intra:61.6% inter:64.5%
# [libx264 @ 0x55920db70dc0] coded y,uvDC,uvAC intra: 59.8% 53.5% 14.1% inter: 22.5% 12.9% 0.4%
# [libx264 @ 0x55920db70dc0] i16 v,h,dc,p: 64%  3% 13% 20%
# [libx264 @ 0x55920db70dc0] i8 v,h,dc,ddl,ddr,vr,hd,vl,hu: 27%  9% 23%  4%  7% 10%  5%  9%  5%
# [libx264 @ 0x55920db70dc0] i4 v,h,dc,ddl,ddr,vr,hd,vl,hu: 30% 11% 21%  6%  7%  8%  5%  7%  4%
# [libx264 @ 0x55920db70dc0] i8c dc,h,v,p: 65%  8% 22%  6%
# [libx264 @ 0x55920db70dc0] Weighted P-Frames: Y:0.0% UV:0.0%
# [libx264 @ 0x55920db70dc0] ref P L0: 65.5% 30.8%  2.6%  1.2%
# [libx264 @ 0x55920db70dc0] ref B L0: 90.8%  7.2%  2.0%
# [libx264 @ 0x55920db70dc0] ref B L1: 97.8%  2.2%
# [libx264 @ 0x55920db70dc0] kb/s:258.91
# 100%|██████████| 16/16 [03:19<00:00, 12.45s/it]
