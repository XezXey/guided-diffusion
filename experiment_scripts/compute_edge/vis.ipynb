# %%
import numpy as np
import torch as th
import glob
from PIL import Image

import matplotlib.pyplot as plt

sj = '60001'
lap_f = f'/data/mint/DPM_Dataset/ffhq_256_with_anno/laplacian/valid/{sj}.npy'
img_f = f'/data/mint/DPM_Dataset/ffhq_256_with_anno/ffhq_256/valid/{sj}.jpg'

img = np.array(Image.open(img_f))
lap = (np.load(lap_f) + 0.5) * 255.0
# lap = (np.load(lap_f) + 1) * 127.5
print(lap.shape)
lap = np.concatenate((lap, lap, lap), axis=2)
# check all 3 channels are the same
print(np.max(lap), np.min(lap))
print(np.max(img), np.min(img))
print(lap.shape)
plt.figure(figsize=(20, 10))
plt.imshow(np.concatenate((img, lap), axis=1).astype(np.uint8))
plt.show()
# Out:
# (256, 256, 1)
# 251.20855712890625 48.33410644531249
# 255 2
# (256, 256, 3)

# %%
import numpy as np
import torch as th
import glob
from PIL import Image

import matplotlib.pyplot as plt

sj = '60001'
lap_f = f'/data/mint/DPM_Dataset/ffhq_256_with_anno/sobel/valid/{sj}.npy'
img_f = f'/data/mint/DPM_Dataset/ffhq_256_with_anno/ffhq_256/valid/{sj}.jpg'

img = np.array(Image.open(img_f)) / 255.0
sob = (np.load(lap_f))
sob = np.concatenate((sob, sob, sob), axis=2)
# check all 3 channels are the same
print(np.max(sob), np.min(sob))
print(np.max(img), np.min(img))
plt.figure(figsize=(20, 10))
plt.imshow(np.concatenate((img, sob), axis=1))
plt.show()
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# 4.081824 0.001
# 1.0 0.00784313725490196
