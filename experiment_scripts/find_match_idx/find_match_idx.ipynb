# %%
import numpy as np
import json
with open('./gen_data_80perc_trainset.json', 'r') as f:
    gen = json.load(f)
    
with open('./top25_shadow_for_rotate.json', 'r') as f:
    all = json.load(f)

# %%
src_gen = [v['src'] for _, v in gen['pair'].items()]
all_gen = [v['src'] for _, v in all['pair'].items()]
print(len(src_gen))
print(len(all_gen))

where_idx = [all_gen.index(sg) for sg in src_gen]
print(sorted(where_idx))
print(len(where_idx))
# Out:
# 921
# 2500
# ...
