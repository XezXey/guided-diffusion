# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt

# %%
# set_ = 'valid'
set_ = 'train'
img = '50037'
Sdiff_SS = f'/data/mint/DPM_Dataset/ffhq_256_with_anno/shadow_diff_SS_with_c_simplified/{set_}/{img}.npy'
Sdiff = f'/data/mint/DPM_Dataset/ffhq_256_with_anno/shadow_diff_with_weight_simplified/{set_}/{img}.npy'
raw = f'/data/mint/DPM_Dataset/ffhq_256_with_anno/ffhq_256/{set_}/{img}.jpg'

Sdiff_SS_img = np.load(Sdiff_SS)
Sdiff_img = np.load(Sdiff)
plt.imshow(Sdiff_SS_img)
plt.title(f'{np.unique(Sdiff_SS_img)}')
plt.show()
plt.imshow(Sdiff_img)
plt.title(f'{np.unique(Sdiff_img)}')
plt.show()
plt.imshow(np.array(Image.open(raw)))
plt.show()
