# %%
import numpy as np
import json

light_path = np.load('./light_params.npy', allow_pickle=True)
print(light_path[0].keys())
print(light_path[0]['t'])
print(light_path[0]['radius'])
print(light_path[0]['angle'])
print(light_path[0]['light_dir'])
# Out:
# dict_keys(['t', 'radius', 'angle', 'light_dir', 'light_conic', 'light_trans', 'diffuse_intensity', 'ambient_color', 'diffuse_exp'])
# 0.0
# 0.8
# 0.0
# (-0.7333333333333334, 8.980743193747258e-17, 0.6798692684790378)
