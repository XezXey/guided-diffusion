# %%
import numpy as np
import glob
import pytorch_lightning as pl
import json

set_ = 'valid'
path = f'/data/mint/DPM_Dataset/generated_dataset_80perc/gen_images/{set_}'

imgs = glob.glob(f'{path}/*.png')
sj_dict = {}
for f in imgs:
    sj_dict[f.split('/')[-1].split('_')[0]] = f

# %%
print(list(sj_dict.keys()))
pl.utilities.seed.seed_everything(47)
out_json_vis = {'pair':{}}
out_json = {'pair':{}}
ext = '.png'
sj = '60000'
for i, src in enumerate(sj_dict.keys()):
    src = src + '.jpg'
    dst = '60000.jpg'
    out_json['pair'][f'pair{i+1}'] = {'src':src, 'dst':dst}

with open(f'/home/mint/difareli-faster/sample_scripts/faster_inference_script/sample_json/gridSH/gen_data_80perc_testset.json', 'w') as fp:
    json.dump(out_json, fp, indent=4)
# Out:
# Global seed set to 47
# ['69878', '69569', '65590', '68603', '68172', '60949', '64219', '60786', '69366', '69947', '66386', '67834', '62437', '64492', '60705', '61956', '63154', '61796', '60221', '62920', '64363', '62162', '66384', '65243', '61777', '67894', '68092', '63630', '64606', '62764', '68657', '64954', '60340', '64162', '66492', '60374', '61837', '67445', '69423', '64463', '67743', '67229', '65247', '61957', '60265', '64769', '61062', '64043', '68306', '69738', '68578', '68884', '63368', '69322', '66591', '60690', '65805', '60655', '62479', '65751', '68480', '60865', '64442', '67159', '65092', '69886', '63848', '62118', '63944', '64053', '65646', '66476', '64845', '63459', '67765', '65964', '69296', '69952', '63057', '61056', '66965', '63605', '66178', '68568', '65608', '60958', '65179', '67635', '68575', '63441', '66446', '61003', '65020', '64436', '68862', '66755', '65678', '61636', '62863', '69936', '69264', '62434', '60785', '64139', '69652', '63957', '68034', '66112', '69398', '63353', '63326', '69744', '69395', '62128', '67580', '66834', '67962', '65578', '67239', '69161', '63462', '67066', '63603', '61295', '63972', '63250', '63172', '67411', '63968', '65298', '63347', '60427', '66651', '61467', '68074', '64461', '64171', '64232', '66495', '64039', '67961', '65208', '61213', '64798', '61633', '62889', '66879', '62969', '67182', '63552', '63644', '63925', '67967', '67554', '63725', '69111', '64857', '60527', '66985', '63884', '68445', '68554', '63445', '62505', '68770', '61780', '66618', '67287', '64284', '69235', '64981', '69830', '62564', '61376', '62661', '62699', '64312', '64786', '60858', '66188', '67043', '68764', '64544', '63367', '68159', '62612', '64406', '69978', '69631', '69562', '69814', '65698', '61022', '63215', '68087', '69592', '63221', '63819', '69226', '61872', '64746', '68287', '62683', '60576', '68390', '62500', '65135', '64143', '65515', '67945', '64077', '62407', '68486', '60268', '60414', '66097', '61492', '69196', '67923', '63769', '66168', '63226', '65638', '69995', '62781', '62567', '68645', '68670', '65067', '66204', '63809']
